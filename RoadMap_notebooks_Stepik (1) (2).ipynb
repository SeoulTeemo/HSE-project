# %%
import requests
import json

# %%
url = 'https://stepik.org/api/courses?page=31'

# %%
data = json.loads(requests.get(url).content)

# %%
data
# Out:
# {'courses': [{'acquired_assets': [],
#    'acquired_skills': [],
#    'actions': {'edit_advanced_settings': {'enabled': False,
#      'needs_permission': 'teach'},
#     'edit_lti': {'enabled': False, 'needs_permission': 'admin'},
#     'edit_reports': {'enabled': False, 'needs_permission': 'teach'},
#     'manage_permissions': {'enabled': False, 'needs_permission': 'admin'},
#     'view_grade_book': {'enabled': False, 'needs_permission': 'assist'},
#     'view_grade_book_page': {'enabled': False, 'needs_permission': 'assist'},
#     'view_reports': {'enabled': False, 'needs_permission': 'teach'}},
#    'admins_group': None,
#    'announcements': [],
#    'assistants_group': None,
#    'authors': [76135168],
#    'begin_date': '2020-06-01T10:00:00Z',
#    'begin_date_source': '2020-06-01T10:00:00Z',
#    'certificate': '',
#    'certificate_cover_org': None,
#    'certificate_distinction_link': None,
#    'certificate_distinction_threshold': None,
#    'certificate_footer': None,
#    'certificate_link': None,
#    'certificate_regular_link': None,
#    'certificate_regular_threshold': None,
#    'certificates_count': 0,
#    'challenges_count': 0,
#    'content_details': [],
#    'continue_url': '/course/73055/continue',
#    'course_format': '',
#    'course_type': 'basic',
#    'cover': '/media/cache/images/courses/73055/cover_2AQ5EgF/143a0f89e43168138712a31c160cc11f.jpg',
#    'create_date': '2020-06-01T08:33:01Z',
#    'currency_code': None,
#    'description': '',
#    'difficulty': None,
#    'discussion_proxy': None,
#    'discussion_threads': [],
#    'discussions_count': 0,
#    'display_price': '-',
#    'end_date': None,
#    'end_date_source': None,
#    'enrollment': None,
#    'first_deadline': None,
#    'first_lesson': 363575,
#    'first_unit': 348318,
#    'grading_policy': 'no_deadlines',
#    'grading_policy_source': 'no_deadlines',
#    'hard_deadline': None,
#    'hard_deadline_source': None,
#    'has_tutors': False,
#    'id': 73055,
#    'instructor_reviews_count': 0,
#    'instructors': [76135168],
#    'intro': '',
#    'intro_video': None,
#    'is_active': True,
#    'is_adaptive': False,
#    'is_archived': False,
#    'is_censored': False,
#    'is_certificate_auto_issued': False,
#    'is_certificate_issued': False,
#    'is_certificate_with_score': False,
#    'is_contest': False,
#    'is_enabled': True,
#    'is_favorite': False,
#    'is_featured': False,
#    'is_idea_compatible': False,
#    'is_paid': False,
#    'is_popular': False,
#    'is_proctored': False,
#    'is_public': True,
#    'is_self_paced': True,
#    'is_unsuitable': False,
#    'issue': None,
#    'language': 'ru',
#    'last_deadline': None,
#    'last_step': '78-73055',
#    'learners_count': 18,
#    'learners_group': None,
#    'learning_format': '',
#    'lessons_count': 47,
#    'lti_consumer_key': '',
#    'lti_private_profile': False,
#    'lti_secret_key': '',
#    'moderators_group': None,
#    'options': {},
#    'owner': 76135168,
#    'peer_reviews_count': 0,
#    'position': 605,
#    'possible_type': None,
#    'price': None,
#    'price_tier': None,
#    'proctor_url': None,
#    'progress': None,
#    'quizzes_count': 0,
#    'readiness': 0.5,
#    'requirements': '',
#    'review_summary': 72603,
#    'schedule_link': None,
#    'schedule_long_link': None,
#    'schedule_type': 'self_paced',
#    'sections': [135577,
#     135283,
#     135547,
#     135559,
#     135561,
#     135564,
#     135576,
#     135572,
#     135699,
#     135702,
#     135703],
#    'slug': 'Нескучный-дистант-73055',
#    'social_providers': [],
#    'soft_deadline': None,
#    'soft_deadline_source': None,
#    'subscriptions': ['31-78-73055', '30-78-73055'],
#    'summary': '',
#    'tags': [],
#    'target_audience': '',
#    'teachers_group': None,
#    'testers_group': None,
#    'time_to_complete': 478,
#    'title': 'Нескучный дистант ',
#    'total_units': 47,
#    'update_date': '2020-06-05T11:13:03Z',
#    'videos_duration': 21139,
#    'workload': ''},
#   {'acquired_assets': [],
#    'acquired_skills': [],
#    'actions': {'edit_advanced_settings': {'enabled': False,
#      'needs_permission': 'teach'},
#     'edit_lti': {'enabled': False, 'needs_permission': 'admin'},
#     'edit_reports': {'enabled': False, 'needs_permission': 'teach'},
#     'manage_permissions': {'enabled': False, 'needs_permission': 'admin'},
#     'view_grade_book': {'enabled': False, 'needs_permission': 'assist'},
#     'view_grade_book_page': {'enabled': False, 'needs_permission': 'assist'},
#     'view_reports': {'enabled': False, 'needs_permission': 'teach'}},
#    'admins_group': None,
#    'announcements': [],
#    'assistants_group': None,
#    'authors': [197442049],
#    'begin_date': '2020-06-01T09:00:00Z',
#    'begin_date_source': '2020-06-01T09:00:00Z',
#    'certificate': '',
#    'certificate_cover_org': None,
#    'certificate_distinction_link': None,
#    'certificate_distinction_threshold': None,
#    'certificate_footer': None,
#    'certificate_link': None,
#    'certificate_regular_link': None,
#    'certificate_regular_threshold': None,
#    'certificates_count': 0,
#    'challenges_count': 0,
#    'content_details': [],
#    'continue_url': '/course/73053/continue',
#    'course_format': '',
#    'course_type': 'basic',
#    'cover': '/media/cache/images/courses/73053/cover_y9YNhrE/84cbe893c7d8da0c7735cc3219caf58d.jpg',
#    'create_date': '2020-06-01T07:43:28Z',
#    'currency_code': None,
#    'description': '<p>За время прохождения этого мини курса, мы с вами познакомимся с\xa0образовательным конструктором Lego, его историей создания, какие наборы существуют на данный момент и самое главное познакомимся с набором и программой по направлению "Юный конструктор Lego"\xa0</p>\n',
#    'difficulty': None,
#    'discussion_proxy': None,
#    'discussion_threads': [],
#    'discussions_count': 0,
#    'display_price': '-',
#    'end_date': None,
#    'end_date_source': None,
#    'enrollment': None,
#    'first_deadline': None,
#    'first_lesson': 362576,
#    'first_unit': 347196,
#    'grading_policy': 'no_deadlines',
#    'grading_policy_source': 'no_deadlines',
#    'hard_deadline': None,
#    'hard_deadline_source': None,
#    'has_tutors': False,
#    'id': 73053,
#    'instructor_reviews_count': 0,
#    'instructors': [197442049],
#    'intro': '',
#    'intro_video': None,
#    'is_active': True,
#    'is_adaptive': False,
#    'is_archived': False,
#    'is_censored': False,
#    'is_certificate_auto_issued': False,
#    'is_certificate_issued': False,
#    'is_certificate_with_score': False,
#    'is_contest': False,
#    'is_enabled': True,
#    'is_favorite': False,
#    'is_featured': False,
#    'is_idea_compatible': False,
#    'is_paid': False,
#    'is_popular': True,
#    'is_proctored': False,
#    'is_public': True,
#    'is_self_paced': True,
#    'is_unsuitable': False,
#    'issue': None,
#    'language': 'ru',
#    'last_deadline': None,
#    'last_step': '78-73053',
#    'learners_count': 24,
#    'learners_group': None,
#    'learning_format': '',
#    'lessons_count': 5,
#    'lti_consumer_key': '',
#    'lti_private_profile': False,
#    'lti_secret_key': '',
#    'moderators_group': None,
#    'options': {},
#    'owner': 197442049,
#    'peer_reviews_count': 0,
#    'position': 607,
#    'possible_type': None,
#    'price': None,
#    'price_tier': None,
#    'proctor_url': None,
#    'progress': None,
#    'quizzes_count': 7,
#    'readiness': 0.8,
#    'requirements': '',
#    'review_summary': 72601,
#    'schedule_link': None,
#    'schedule_long_link': None,
#    'schedule_type': 'self_paced',
#    'sections': [135282, 135287, 135642, 136104, 136515],
#    'slug': 'Знакомство-с-образовательным-конструктором-Lego-73053',
#    'social_providers': [],
#    'soft_deadline': None,
#    'soft_deadline_source': None,
#    'subscriptions': ['31-78-73053', '30-78-73053'],
#    'summary': 'За время прохождения этого мини курса, мы с вами познакомимся с\xa0образовательным конструктором Lego, его историей создания, какие наборы существуют на данный момент и самое главное познакомимся с набором и программой по направлению "Юный конструктор Lego"\xa0                                                                                                                                                            \n                                                                                          \n                                                                                            \n                                                                                         \n                                                                                          \n                                                                                               \n                                        ',
#    'tags': [],
#    'target_audience': 'Уверенный пользователь',
#    'teachers_group': None,
#    'testers_group': None,
#    'time_to_complete': 2269,
#    'title': 'Знакомство с образовательным конструктором Lego',
#    'total_units': 5,
#    'update_date': '2020-06-16T01:24:34Z',
#    'videos_duration': 1511,
#    'workload': '3 часа в неделю'},
#   {'acquired_assets': [],
#    'acquired_skills': [],
#    'actions': {'edit_advanced_settings': {'enabled': False,
#      'needs_permission': 'teach'},
#     'edit_lti': {'enabled': False, 'needs_permission': 'admin'},
#     'edit_reports': {'enabled': False, 'needs_permission': 'teach'},
#     'manage_permissions': {'enabled': False, 'needs_permission': 'admin'},
#     'view_grade_book': {'enabled': False, 'needs_permission': 'assist'},
#     'view_grade_book_page': {'enabled': False, 'needs_permission': 'assist'},
#     'view_reports': {'enabled': False, 'needs_permission': 'teach'}},
#    'admins_group': None,
#    'announcements': [],
#    'assistants_group': None,
#    'authors': [214118610],
#    'begin_date': None,
#    'begin_date_source': None,
#    'certificate': '',
#    'certificate_cover_org': None,
#    'certificate_distinction_link': None,
#    'certificate_distinction_threshold': None,
#    'certificate_footer': None,
#    'certificate_link': None,
#    'certificate_regular_link': None,
#    'certificate_regular_threshold': None,
#    'certificates_count': 0,
#    'challenges_count': 0,
#    'content_details': [],
#    'continue_url': '/course/73051/continue',
#    'course_format': '',
#    'course_type': 'basic',
#    'cover': '/media/cache/images/courses/73051/cover_CfuuRpq/3b3c494e918dd8718296fa3ee0e06184.jpg',
#    'create_date': '2020-06-01T07:12:28Z',
#    'currency_code': None,
#    'description': '<p>Курс предназначен для повторения и систематизации знаний за курс 7 класса. \xa0УМК А.Г. Мерзляк , базового и профильного уровня подготовки.</p>\n\n<p>В курсе представлены следующие темы:</p>\n\n<p>-Линейные уравнения с одной переменной</p>\n\n<p>-Целые выражения</p>\n\n<p>-Функции</p>\n\n<p>-Системы линейных уравнений с двумя переменными и методы их решений</p>\n\n<p>Для прохождения курса не требуется дополнительных материалов, достаточно навыков счета.</p>\n\n<p>В каждой теме предложены задания с примерами.</p>\n\n<p>Каждая глава содержит краткую выжимку из темы, что позволяет не использовать дополнительную литературу по данной теме.\xa0</p>\n\n<p>Успехов в учебе \xa0и отличного настроения!</p>\n',
#    'difficulty': None,
#    'discussion_proxy': None,
#    'discussion_threads': [],
#    'discussions_count': 0,
#    'display_price': '-',
#    'end_date': None,
#    'end_date_source': None,
#    'enrollment': None,
#    'first_deadline': None,
#    'first_lesson': 362558,
#    'first_unit': 347175,
#    'grading_policy': 'no_deadlines',
#    'grading_policy_source': 'no_deadlines',
#    'hard_deadline': None,
#    'hard_deadline_source': None,
#    'has_tutors': False,
#    'id': 73051,
#    'instructor_reviews_count': 0,
#    'instructors': [214118610],
#    'intro': '',
#    'intro_video': None,
#    'is_active': True,
#    'is_adaptive': False,
#    'is_archived': False,
#    'is_censored': False,
#    'is_certificate_auto_issued': False,
#    'is_certificate_issued': False,
#    'is_certificate_with_score': False,
#    'is_contest': False,
#    'is_enabled': True,
#    'is_favorite': False,
#    'is_featured': False,
#    'is_idea_compatible': False,
#    'is_paid': False,
#    'is_popular': False,
#    'is_proctored': False,
#    'is_public': True,
#    'is_self_paced': False,
#    'is_unsuitable': False,
#    'issue': None,
#    'language': 'ru',
#    'last_deadline': None,
#    'last_step': '78-73051',
#    'learners_count': 1,
#    'learners_group': None,
#    'learning_format': '',
#    'lessons_count': 21,
#    'lti_consumer_key': '',
#    'lti_private_profile': False,
#    'lti_secret_key': '',
#    'moderators_group': None,
#    'options': {},
#    'owner': 214118610,
#    'peer_reviews_count': 0,
#    'position': 609,
#    'possible_type': None,
#    'price': None,
#    'price_tier': None,
#    'proctor_url': None,
#    'progress': None,
#    'quizzes_count': 166,
#    'readiness': 1.0,
#    'requirements': '<p>Умение выполнять любые арифметические действия и желание повторить когда-то изученный материал</p>\n',
#    'review_summary': 72599,
#    'schedule_link': None,
#    'schedule_long_link': None,
#    'schedule_type': 'upcoming',
#    'sections': [135269, 135270, 135271, 135272, 136499],
#    'slug': 'Алгебра-7-класс-УМК-АГ-Мерзляк-73051',
#    'social_providers': [],
#    'soft_deadline': None,
#    'soft_deadline_source': None,
#    'subscriptions': ['31-78-73051', '30-78-73051'],
#    'summary': 'Курс предназначен для повторения и систематизации знаний за курс 7 класса. \xa0УМК А.Г. Мерзляк\nВ каждой теме предложены задания с примерами, что облегчит выполнение заданий.',
#    'tags': [],
#    'target_audience': 'Любой пользователь',
#    'teachers_group': None,
#    'testers_group': None,
#    'time_to_complete': None,
#    'title': 'Алгебра  7 класс УМК А.Г. Мерзляк',
#    'total_units': 21,
#    'update_date': '2020-06-14T07:48:18Z',
#    'videos_duration': 0,
#    'workload': '1 час в неделю'},
#   {'acquired_assets': [],
#    'acquired_skills': [],
#    'actions': {'edit_advanced_settings': {'enabled': False,
#      'needs_permission': 'teach'},
#     'edit_lti': {'enabled': False, 'needs_permission': 'admin'},
#     'edit_reports': {'enabled': False, 'needs_permission': 'teach'},
#     'manage_permissions': {'enabled': False, 'needs_permission': 'admin'},
#     'view_grade_book': {'enabled': False, 'needs_permission': 'assist'},
#     'view_grade_book_page': {'enabled': False, 'needs_permission': 'assist'},
#     'view_reports': {'enabled': False, 'needs_permission': 'teach'}},
#    'admins_group': None,
#    'announcements': [],
#    'assistants_group': None,
#    'authors': [58654552],
#    'begin_date': None,
#    'begin_date_source': None,
#    'certificate': '',
#    'certificate_cover_org': None,
#    'certificate_distinction_link': None,
#    'certificate_distinction_threshold': None,
#    'certificate_footer': None,
#    'certificate_link': None,
#    'certificate_regular_link': None,
#    'certificate_regular_threshold': None,
#    'certificates_count': 0,
#    'challenges_count': 0,
#    'content_details': [],
#    'continue_url': '/course/73048/continue',
#    'course_format': '',
#    'course_type': 'legacy',
#    'cover': '/media/cache/images/courses/62312/cover_MJjWpaF/c82bacf84e35e854b84556bac2ba0a3f.png',
#    'create_date': '2020-06-01T04:47:36Z',
#    'currency_code': None,
#    'description': '<p>Логиканы игере отырып есептеудi, ойлауды, талдауды, әртүрлi есептердiң шешiмдерiн табуды үйренесiңдер.</p>\n\n<p>4,5,6\xa0сынып логика курсында сендер ойлау қабілеттеріңді\xa0жетiлдiресiңдер.</p>\n\n<p>Логикалық ойлау\xa0құпияларын ашуда сендерге табыс тiлеймiз!</p>\n',
#    'difficulty': None,
#    'discussion_proxy': None,
#    'discussion_threads': [],
#    'discussions_count': 0,
#    'display_price': '-',
#    'end_date': None,
#    'end_date_source': None,
#    'enrollment': None,
#    'first_deadline': None,
#    'first_lesson': 342964,
#    'first_unit': 347114,
#    'grading_policy': 'halved',
#    'grading_policy_source': 'halved',
#    'hard_deadline': None,
#    'hard_deadline_source': None,
#    'has_tutors': False,
#    'id': 73048,
#    'instructor_reviews_count': 0,
#    'instructors': [],
#    'intro': '',
#    'intro_video': None,
#    'is_active': True,
#    'is_adaptive': False,
#    'is_archived': False,
#    'is_censored': False,
#    'is_certificate_auto_issued': False,
#    'is_certificate_issued': False,
#    'is_certificate_with_score': True,
#    'is_contest': False,
#    'is_enabled': True,
#    'is_favorite': False,
#    'is_featured': False,
#    'is_idea_compatible': False,
#    'is_paid': False,
#    'is_popular': False,
#    'is_proctored': False,
#    'is_public': True,
#    'is_self_paced': True,
#    'is_unsuitable': False,
#    'issue': None,
#    'language': 'kk',
#    'last_deadline': None,
#    'last_step': '78-73048',
#    'learners_count': 7,
#    'learners_group': None,
#    'learning_format': '',
#    'lessons_count': 66,
#    'lti_consumer_key': '',
#    'lti_private_profile': False,
#    'lti_secret_key': '',
#    'moderators_group': None,
#    'options': {},
#    'owner': 140685666,
#    'peer_reviews_count': 0,
#    'position': 612,
#    'possible_type': None,
#    'price': None,
#    'price_tier': None,
#    'proctor_url': None,
#    'progress': None,
#    'quizzes_count': 637,
#    'readiness': 0.7,
#    'requirements': '\n    <p>5 математикасын орта деңгейде білу</p>\n\n  ',
#    'review_summary': 72596,
#    'schedule_link': None,
#    'schedule_long_link': None,
#    'schedule_type': 'self_paced',
#    'sections': [135253,
#     135254,
#     135255,
#     135256,
#     135257,
#     135258,
#     135259,
#     135260,
#     135261,
#     135262,
#     135264,
#     135273,
#     135266,
#     135267,
#     135268,
#     137328,
#     137329,
#     137330,
#     137331,
#     137332,
#     137333,
#     137334],
#    'slug': 'Логикаңды-дамыт-курсы-NEW-73048',
#    'social_providers': [],
#    'soft_deadline': None,
#    'soft_deadline_source': None,
#    'subscriptions': ['31-78-73048', '30-78-73048'],
#    'summary': '',
#    'tags': [],
#    'target_audience': 'КТЛ, НЗМ-ге дайындалуға арналған онлайн  курс',
#    'teachers_group': None,
#    'testers_group': None,
#    'time_to_complete': 15352,
#    'title': '"Логикаңды дамыт" курсы NEW',
#    'total_units': 66,
#    'update_date': '2020-06-17T08:27:28Z',
#    'videos_duration': 1367,
#    'workload': 'Күніне 50-100 минут жаттығу керек'},
#   {'acquired_assets': [],
#    'acquired_skills': [],
#    'actions': {'edit_advanced_settings': {'enabled': False,
#      'needs_permission': 'teach'},
#     'edit_lti': {'enabled': False, 'needs_permission': 'admin'},
#     'edit_reports': {'enabled': False, 'needs_permission': 'teach'},
#     'manage_permissions': {'enabled': False, 'needs_permission': 'admin'},
#     'view_grade_book': {'enabled': False, 'needs_permission': 'assist'},
#     'view_grade_book_page': {'enabled': False, 'needs_permission': 'assist'},
#     'view_reports': {'enabled': False, 'needs_permission': 'teach'}},
#    'admins_group': None,
#    'announcements': [],
#    'assistants_group': None,
#    'authors': [239058847],
#    'begin_date': '2020-05-31T22:36:36Z',
#    'begin_date_source': '2020-05-31T22:36:36Z',
#    'certificate': '',
#    'certificate_cover_org': None,
#    'certificate_distinction_link': None,
#    'certificate_distinction_threshold': None,
#    'certificate_footer': None,
#    'certificate_link': None,
#    'certificate_regular_link': None,
#    'certificate_regular_threshold': None,
#    'certificates_count': 0,
#    'challenges_count': 0,
#    'content_details': [],
#    'continue_url': '/course/73045/continue',
#    'course_format': '',
#    'course_type': 'basic',
#    'cover': '/media/cache/images/courses/73045/cover_LAxvQlG/b56ac603a5d2ffd5521f85f10f5853f2.jpeg',
#    'create_date': '2020-05-31T22:36:22Z',
#    'currency_code': None,
#    'description': '<p>Эпоксидная смола—универсальный материал, из которого можно сотворить что угодно и как угодно. Я предлагаю Вам попробовать сделать уникальный кулон!)\xa0</p>\n',
#    'difficulty': None,
#    'discussion_proxy': None,
#    'discussion_threads': [],
#    'discussions_count': 0,
#    'display_price': '-',
#    'end_date': None,
#    'end_date_source': None,
#    'enrollment': None,
#    'first_deadline': None,
#    'first_lesson': None,
#    'first_unit': None,
#    'grading_policy': 'no_deadlines',
#    'grading_policy_source': 'no_deadlines',
#    'hard_deadline': None,
#    'hard_deadline_source': None,
#    'has_tutors': False,
#    'id': 73045,
#    'instructor_reviews_count': 0,
#    'instructors': [239058847],
#    'intro': '',
#    'intro_video': None,
#    'is_active': True,
#    'is_adaptive': False,
#    'is_archived': False,
#    'is_censored': False,
#    'is_certificate_auto_issued': False,
#    'is_certificate_issued': False,
#    'is_certificate_with_score': False,
#    'is_contest': False,
#    'is_enabled': True,
#    'is_favorite': False,
#    'is_featured': False,
#    'is_idea_compatible': False,
#    'is_paid': False,
#    'is_popular': False,
#    'is_proctored': False,
#    'is_public': True,
#    'is_self_paced': True,
#    'is_unsuitable': False,
#    'issue': None,
#    'language': 'ru',
#    'last_deadline': None,
#    'last_step': '78-73045',
#    'learners_count': 2,
#    'learners_group': None,
#    'learning_format': '',
#    'lessons_count': 0,
#    'lti_consumer_key': '',
#    'lti_private_profile': False,
#    'lti_secret_key': '',
#    'moderators_group': None,
#    'options': {},
#    'owner': 239058847,
#    'peer_reviews_count': 0,
#    'position': 615,
#    'possible_type': None,
#    'price': None,
#    'price_tier': None,
#    'proctor_url': None,
#    'progress': None,
#    'quizzes_count': 0,
#    'readiness': 0.4,
#    'requirements': '',
#    'review_summary': 72593,
#    'schedule_link': None,
#    'schedule_long_link': None,
#    'schedule_type': 'self_paced',
#    'sections': [135197,
#     135198,
#     135199,
#     135200,
#     135201,
#     135202,
#     135203,
#     135300],
#    'slug': 'Кулоны-из-эпоксидной-смолы-73045',
#    'social_providers': [],
#    'soft_deadline': None,
#    'soft_deadline_source': None,
#    'subscriptions': ['31-78-73045', '30-78-73045'],
#    'summary': '',
#    'tags': [],
#    'target_audience': '',
#    'teachers_group': None,
#    'testers_group': None,
#    'time_to_complete': None,
#    'title': 'Кулоны из эпоксидной смолы',
#    'total_units': 0,
#    'update_date': '2020-06-02T05:28:20Z',
#    'videos_duration': 0,
#    'workload': ''}],
#  'enrollments': [],
#  'meta': {'has_next': True, 'has_previous': True, 'page': 31}}

# %%
url = 'https://stepik.org/api/courses?page={}'
data = json.loads(requests.get(url.format(31)).content)
cols = list(data['courses'][0].keys())
cols
# Out:
# ['id',
#  'summary',
#  'workload',
#  'cover',
#  'intro',
#  'course_format',
#  'target_audience',
#  'certificate_footer',
#  'certificate_cover_org',
#  'is_certificate_issued',
#  'is_certificate_auto_issued',
#  'certificate_regular_threshold',
#  'certificate_distinction_threshold',
#  'instructors',
#  'certificate',
#  'requirements',
#  'description',
#  'sections',
#  'total_units',
#  'enrollment',
#  'is_favorite',
#  'actions',
#  'progress',
#  'first_lesson',
#  'first_unit',
#  'certificate_link',
#  'certificate_regular_link',
#  'certificate_distinction_link',
#  'schedule_link',
#  'schedule_long_link',
#  'first_deadline',
#  'last_deadline',
#  'subscriptions',
#  'announcements',
#  'is_contest',
#  'is_self_paced',
#  'is_adaptive',
#  'is_idea_compatible',
#  'last_step',
#  'intro_video',
#  'social_providers',
#  'authors',
#  'tags',
#  'has_tutors',
#  'is_enabled',
#  'is_proctored',
#  'proctor_url',
#  'review_summary',
#  'schedule_type',
#  'certificates_count',
#  'learners_count',
#  'lessons_count',
#  'quizzes_count',
#  'challenges_count',
#  'peer_reviews_count',
#  'instructor_reviews_count',
#  'videos_duration',
#  'time_to_complete',
#  'is_popular',
#  'is_unsuitable',
#  'is_paid',
#  'price',
#  'currency_code',
#  'display_price',
#  'continue_url',
#  'readiness',
#  'is_archived',
#  'options',
#  'price_tier',
#  'position',
#  'is_censored',
#  'difficulty',
#  'acquired_skills',
#  'acquired_assets',
#  'learning_format',
#  'content_details',
#  'issue',
#  'course_type',
#  'possible_type',
#  'is_certificate_with_score',
#  'owner',
#  'language',
#  'is_featured',
#  'is_public',
#  'title',
#  'slug',
#  'begin_date',
#  'end_date',
#  'soft_deadline',
#  'hard_deadline',
#  'grading_policy',
#  'begin_date_source',
#  'end_date_source',
#  'soft_deadline_source',
#  'hard_deadline_source',
#  'grading_policy_source',
#  'is_active',
#  'create_date',
#  'update_date',
#  'learners_group',
#  'testers_group',
#  'moderators_group',
#  'assistants_group',
#  'teachers_group',
#  'admins_group',
#  'discussions_count',
#  'discussion_proxy',
#  'discussion_threads',
#  'lti_consumer_key',
#  'lti_secret_key',
#  'lti_private_profile']

# %%
data['courses']
# Out:
# [{'acquired_assets': [],
#   'acquired_skills': [],
#   'actions': {'edit_advanced_settings': {'enabled': False,
#     'needs_permission': 'teach'},
#    'edit_lti': {'enabled': False, 'needs_permission': 'admin'},
#    'edit_reports': {'enabled': False, 'needs_permission': 'teach'},
#    'manage_permissions': {'enabled': False, 'needs_permission': 'admin'},
#    'view_grade_book': {'enabled': False, 'needs_permission': 'assist'},
#    'view_grade_book_page': {'enabled': False, 'needs_permission': 'assist'},
#    'view_reports': {'enabled': False, 'needs_permission': 'teach'}},
#   'admins_group': None,
#   'announcements': [],
#   'assistants_group': None,
#   'authors': [76135168],
#   'begin_date': '2020-06-01T10:00:00Z',
#   'begin_date_source': '2020-06-01T10:00:00Z',
#   'certificate': '',
#   'certificate_cover_org': None,
#   'certificate_distinction_link': None,
#   'certificate_distinction_threshold': None,
#   'certificate_footer': None,
#   'certificate_link': None,
#   'certificate_regular_link': None,
#   'certificate_regular_threshold': None,
#   'certificates_count': 0,
#   'challenges_count': 0,
#   'content_details': [],
#   'continue_url': '/course/73055/continue',
#   'course_format': '',
#   'course_type': 'basic',
#   'cover': '/media/cache/images/courses/73055/cover_2AQ5EgF/143a0f89e43168138712a31c160cc11f.jpg',
#   'create_date': '2020-06-01T08:33:01Z',
#   'currency_code': None,
#   'description': '',
#   'difficulty': None,
#   'discussion_proxy': None,
#   'discussion_threads': [],
#   'discussions_count': 0,
#   'display_price': '-',
#   'end_date': None,
#   'end_date_source': None,
#   'enrollment': None,
#   'first_deadline': None,
#   'first_lesson': 363575,
#   'first_unit': 348318,
#   'grading_policy': 'no_deadlines',
#   'grading_policy_source': 'no_deadlines',
#   'hard_deadline': None,
#   'hard_deadline_source': None,
#   'has_tutors': False,
#   'id': 73055,
#   'instructor_reviews_count': 0,
#   'instructors': [76135168],
#   'intro': '',
#   'intro_video': None,
#   'is_active': True,
#   'is_adaptive': False,
#   'is_archived': False,
#   'is_censored': False,
#   'is_certificate_auto_issued': False,
#   'is_certificate_issued': False,
#   'is_certificate_with_score': False,
#   'is_contest': False,
#   'is_enabled': True,
#   'is_favorite': False,
#   'is_featured': False,
#   'is_idea_compatible': False,
#   'is_paid': False,
#   'is_popular': False,
#   'is_proctored': False,
#   'is_public': True,
#   'is_self_paced': True,
#   'is_unsuitable': False,
#   'issue': None,
#   'language': 'ru',
#   'last_deadline': None,
#   'last_step': '78-73055',
#   'learners_count': 18,
#   'learners_group': None,
#   'learning_format': '',
#   'lessons_count': 47,
#   'lti_consumer_key': '',
#   'lti_private_profile': False,
#   'lti_secret_key': '',
#   'moderators_group': None,
#   'options': {},
#   'owner': 76135168,
#   'peer_reviews_count': 0,
#   'position': 605,
#   'possible_type': None,
#   'price': None,
#   'price_tier': None,
#   'proctor_url': None,
#   'progress': None,
#   'quizzes_count': 0,
#   'readiness': 0.5,
#   'requirements': '',
#   'review_summary': 72603,
#   'schedule_link': None,
#   'schedule_long_link': None,
#   'schedule_type': 'self_paced',
#   'sections': [135577,
#    135283,
#    135547,
#    135559,
#    135561,
#    135564,
#    135576,
#    135572,
#    135699,
#    135702,
#    135703],
#   'slug': 'Нескучный-дистант-73055',
#   'social_providers': [],
#   'soft_deadline': None,
#   'soft_deadline_source': None,
#   'subscriptions': ['31-78-73055', '30-78-73055'],
#   'summary': '',
#   'tags': [],
#   'target_audience': '',
#   'teachers_group': None,
#   'testers_group': None,
#   'time_to_complete': 478,
#   'title': 'Нескучный дистант ',
#   'total_units': 47,
#   'update_date': '2020-06-05T11:13:03Z',
#   'videos_duration': 21139,
#   'workload': ''},
#  {'acquired_assets': [],
#   'acquired_skills': [],
#   'actions': {'edit_advanced_settings': {'enabled': False,
#     'needs_permission': 'teach'},
#    'edit_lti': {'enabled': False, 'needs_permission': 'admin'},
#    'edit_reports': {'enabled': False, 'needs_permission': 'teach'},
#    'manage_permissions': {'enabled': False, 'needs_permission': 'admin'},
#    'view_grade_book': {'enabled': False, 'needs_permission': 'assist'},
#    'view_grade_book_page': {'enabled': False, 'needs_permission': 'assist'},
#    'view_reports': {'enabled': False, 'needs_permission': 'teach'}},
#   'admins_group': None,
#   'announcements': [],
#   'assistants_group': None,
#   'authors': [197442049],
#   'begin_date': '2020-06-01T09:00:00Z',
#   'begin_date_source': '2020-06-01T09:00:00Z',
#   'certificate': '',
#   'certificate_cover_org': None,
#   'certificate_distinction_link': None,
#   'certificate_distinction_threshold': None,
#   'certificate_footer': None,
#   'certificate_link': None,
#   'certificate_regular_link': None,
#   'certificate_regular_threshold': None,
#   'certificates_count': 0,
#   'challenges_count': 0,
#   'content_details': [],
#   'continue_url': '/course/73053/continue',
#   'course_format': '',
#   'course_type': 'basic',
#   'cover': '/media/cache/images/courses/73053/cover_y9YNhrE/84cbe893c7d8da0c7735cc3219caf58d.jpg',
#   'create_date': '2020-06-01T07:43:28Z',
#   'currency_code': None,
#   'description': '<p>За время прохождения этого мини курса, мы с вами познакомимся с\xa0образовательным конструктором Lego, его историей создания, какие наборы существуют на данный момент и самое главное познакомимся с набором и программой по направлению "Юный конструктор Lego"\xa0</p>\n',
#   'difficulty': None,
#   'discussion_proxy': None,
#   'discussion_threads': [],
#   'discussions_count': 0,
#   'display_price': '-',
#   'end_date': None,
#   'end_date_source': None,
#   'enrollment': None,
#   'first_deadline': None,
#   'first_lesson': 362576,
#   'first_unit': 347196,
#   'grading_policy': 'no_deadlines',
#   'grading_policy_source': 'no_deadlines',
#   'hard_deadline': None,
#   'hard_deadline_source': None,
#   'has_tutors': False,
#   'id': 73053,
#   'instructor_reviews_count': 0,
#   'instructors': [197442049],
#   'intro': '',
#   'intro_video': None,
#   'is_active': True,
#   'is_adaptive': False,
#   'is_archived': False,
#   'is_censored': False,
#   'is_certificate_auto_issued': False,
#   'is_certificate_issued': False,
#   'is_certificate_with_score': False,
#   'is_contest': False,
#   'is_enabled': True,
#   'is_favorite': False,
#   'is_featured': False,
#   'is_idea_compatible': False,
#   'is_paid': False,
#   'is_popular': True,
#   'is_proctored': False,
#   'is_public': True,
#   'is_self_paced': True,
#   'is_unsuitable': False,
#   'issue': None,
#   'language': 'ru',
#   'last_deadline': None,
#   'last_step': '78-73053',
#   'learners_count': 24,
#   'learners_group': None,
#   'learning_format': '',
#   'lessons_count': 5,
#   'lti_consumer_key': '',
#   'lti_private_profile': False,
#   'lti_secret_key': '',
#   'moderators_group': None,
#   'options': {},
#   'owner': 197442049,
#   'peer_reviews_count': 0,
#   'position': 607,
#   'possible_type': None,
#   'price': None,
#   'price_tier': None,
#   'proctor_url': None,
#   'progress': None,
#   'quizzes_count': 7,
#   'readiness': 0.8,
#   'requirements': '',
#   'review_summary': 72601,
#   'schedule_link': None,
#   'schedule_long_link': None,
#   'schedule_type': 'self_paced',
#   'sections': [135282, 135287, 135642, 136104, 136515],
#   'slug': 'Знакомство-с-образовательным-конструктором-Lego-73053',
#   'social_providers': [],
#   'soft_deadline': None,
#   'soft_deadline_source': None,
#   'subscriptions': ['31-78-73053', '30-78-73053'],
#   'summary': 'За время прохождения этого мини курса, мы с вами познакомимся с\xa0образовательным конструктором Lego, его историей создания, какие наборы существуют на данный момент и самое главное познакомимся с набором и программой по направлению "Юный конструктор Lego"\xa0                                                                                                                                                            \n                                                                                          \n                                                                                            \n                                                                                         \n                                                                                          \n                                                                                               \n                                        ',
#   'tags': [],
#   'target_audience': 'Уверенный пользователь',
#   'teachers_group': None,
#   'testers_group': None,
#   'time_to_complete': 2269,
#   'title': 'Знакомство с образовательным конструктором Lego',
#   'total_units': 5,
#   'update_date': '2020-06-16T01:24:34Z',
#   'videos_duration': 1511,
#   'workload': '3 часа в неделю'},
#  {'acquired_assets': [],
#   'acquired_skills': [],
#   'actions': {'edit_advanced_settings': {'enabled': False,
#     'needs_permission': 'teach'},
#    'edit_lti': {'enabled': False, 'needs_permission': 'admin'},
#    'edit_reports': {'enabled': False, 'needs_permission': 'teach'},
#    'manage_permissions': {'enabled': False, 'needs_permission': 'admin'},
#    'view_grade_book': {'enabled': False, 'needs_permission': 'assist'},
#    'view_grade_book_page': {'enabled': False, 'needs_permission': 'assist'},
#    'view_reports': {'enabled': False, 'needs_permission': 'teach'}},
#   'admins_group': None,
#   'announcements': [],
#   'assistants_group': None,
#   'authors': [214118610],
#   'begin_date': None,
#   'begin_date_source': None,
#   'certificate': '',
#   'certificate_cover_org': None,
#   'certificate_distinction_link': None,
#   'certificate_distinction_threshold': None,
#   'certificate_footer': None,
#   'certificate_link': None,
#   'certificate_regular_link': None,
#   'certificate_regular_threshold': None,
#   'certificates_count': 0,
#   'challenges_count': 0,
#   'content_details': [],
#   'continue_url': '/course/73051/continue',
#   'course_format': '',
#   'course_type': 'basic',
#   'cover': '/media/cache/images/courses/73051/cover_CfuuRpq/3b3c494e918dd8718296fa3ee0e06184.jpg',
#   'create_date': '2020-06-01T07:12:28Z',
#   'currency_code': None,
#   'description': '<p>Курс предназначен для повторения и систематизации знаний за курс 7 класса. \xa0УМК А.Г. Мерзляк , базового и профильного уровня подготовки.</p>\n\n<p>В курсе представлены следующие темы:</p>\n\n<p>-Линейные уравнения с одной переменной</p>\n\n<p>-Целые выражения</p>\n\n<p>-Функции</p>\n\n<p>-Системы линейных уравнений с двумя переменными и методы их решений</p>\n\n<p>Для прохождения курса не требуется дополнительных материалов, достаточно навыков счета.</p>\n\n<p>В каждой теме предложены задания с примерами.</p>\n\n<p>Каждая глава содержит краткую выжимку из темы, что позволяет не использовать дополнительную литературу по данной теме.\xa0</p>\n\n<p>Успехов в учебе \xa0и отличного настроения!</p>\n',
#   'difficulty': None,
#   'discussion_proxy': None,
#   'discussion_threads': [],
#   'discussions_count': 0,
#   'display_price': '-',
#   'end_date': None,
#   'end_date_source': None,
#   'enrollment': None,
#   'first_deadline': None,
#   'first_lesson': 362558,
#   'first_unit': 347175,
#   'grading_policy': 'no_deadlines',
#   'grading_policy_source': 'no_deadlines',
#   'hard_deadline': None,
#   'hard_deadline_source': None,
#   'has_tutors': False,
#   'id': 73051,
#   'instructor_reviews_count': 0,
#   'instructors': [214118610],
#   'intro': '',
#   'intro_video': None,
#   'is_active': True,
#   'is_adaptive': False,
#   'is_archived': False,
#   'is_censored': False,
#   'is_certificate_auto_issued': False,
#   'is_certificate_issued': False,
#   'is_certificate_with_score': False,
#   'is_contest': False,
#   'is_enabled': True,
#   'is_favorite': False,
#   'is_featured': False,
#   'is_idea_compatible': False,
#   'is_paid': False,
#   'is_popular': False,
#   'is_proctored': False,
#   'is_public': True,
#   'is_self_paced': False,
#   'is_unsuitable': False,
#   'issue': None,
#   'language': 'ru',
#   'last_deadline': None,
#   'last_step': '78-73051',
#   'learners_count': 1,
#   'learners_group': None,
#   'learning_format': '',
#   'lessons_count': 21,
#   'lti_consumer_key': '',
#   'lti_private_profile': False,
#   'lti_secret_key': '',
#   'moderators_group': None,
#   'options': {},
#   'owner': 214118610,
#   'peer_reviews_count': 0,
#   'position': 609,
#   'possible_type': None,
#   'price': None,
#   'price_tier': None,
#   'proctor_url': None,
#   'progress': None,
#   'quizzes_count': 166,
#   'readiness': 1.0,
#   'requirements': '<p>Умение выполнять любые арифметические действия и желание повторить когда-то изученный материал</p>\n',
#   'review_summary': 72599,
#   'schedule_link': None,
#   'schedule_long_link': None,
#   'schedule_type': 'upcoming',
#   'sections': [135269, 135270, 135271, 135272, 136499],
#   'slug': 'Алгебра-7-класс-УМК-АГ-Мерзляк-73051',
#   'social_providers': [],
#   'soft_deadline': None,
#   'soft_deadline_source': None,
#   'subscriptions': ['31-78-73051', '30-78-73051'],
#   'summary': 'Курс предназначен для повторения и систематизации знаний за курс 7 класса. \xa0УМК А.Г. Мерзляк\nВ каждой теме предложены задания с примерами, что облегчит выполнение заданий.',
#   'tags': [],
#   'target_audience': 'Любой пользователь',
#   'teachers_group': None,
#   'testers_group': None,
#   'time_to_complete': None,
#   'title': 'Алгебра  7 класс УМК А.Г. Мерзляк',
#   'total_units': 21,
#   'update_date': '2020-06-14T07:48:18Z',
#   'videos_duration': 0,
#   'workload': '1 час в неделю'},
#  {'acquired_assets': [],
#   'acquired_skills': [],
#   'actions': {'edit_advanced_settings': {'enabled': False,
#     'needs_permission': 'teach'},
#    'edit_lti': {'enabled': False, 'needs_permission': 'admin'},
#    'edit_reports': {'enabled': False, 'needs_permission': 'teach'},
#    'manage_permissions': {'enabled': False, 'needs_permission': 'admin'},
#    'view_grade_book': {'enabled': False, 'needs_permission': 'assist'},
#    'view_grade_book_page': {'enabled': False, 'needs_permission': 'assist'},
#    'view_reports': {'enabled': False, 'needs_permission': 'teach'}},
#   'admins_group': None,
#   'announcements': [],
#   'assistants_group': None,
#   'authors': [58654552],
#   'begin_date': None,
#   'begin_date_source': None,
#   'certificate': '',
#   'certificate_cover_org': None,
#   'certificate_distinction_link': None,
#   'certificate_distinction_threshold': None,
#   'certificate_footer': None,
#   'certificate_link': None,
#   'certificate_regular_link': None,
#   'certificate_regular_threshold': None,
#   'certificates_count': 0,
#   'challenges_count': 0,
#   'content_details': [],
#   'continue_url': '/course/73048/continue',
#   'course_format': '',
#   'course_type': 'legacy',
#   'cover': '/media/cache/images/courses/62312/cover_MJjWpaF/c82bacf84e35e854b84556bac2ba0a3f.png',
#   'create_date': '2020-06-01T04:47:36Z',
#   'currency_code': None,
#   'description': '<p>Логиканы игере отырып есептеудi, ойлауды, талдауды, әртүрлi есептердiң шешiмдерiн табуды үйренесiңдер.</p>\n\n<p>4,5,6\xa0сынып логика курсында сендер ойлау қабілеттеріңді\xa0жетiлдiресiңдер.</p>\n\n<p>Логикалық ойлау\xa0құпияларын ашуда сендерге табыс тiлеймiз!</p>\n',
#   'difficulty': None,
#   'discussion_proxy': None,
#   'discussion_threads': [],
#   'discussions_count': 0,
#   'display_price': '-',
#   'end_date': None,
#   'end_date_source': None,
#   'enrollment': None,
#   'first_deadline': None,
#   'first_lesson': 342964,
#   'first_unit': 347114,
#   'grading_policy': 'halved',
#   'grading_policy_source': 'halved',
#   'hard_deadline': None,
#   'hard_deadline_source': None,
#   'has_tutors': False,
#   'id': 73048,
#   'instructor_reviews_count': 0,
#   'instructors': [],
#   'intro': '',
#   'intro_video': None,
#   'is_active': True,
#   'is_adaptive': False,
#   'is_archived': False,
#   'is_censored': False,
#   'is_certificate_auto_issued': False,
#   'is_certificate_issued': False,
#   'is_certificate_with_score': True,
#   'is_contest': False,
#   'is_enabled': True,
#   'is_favorite': False,
#   'is_featured': False,
#   'is_idea_compatible': False,
#   'is_paid': False,
#   'is_popular': False,
#   'is_proctored': False,
#   'is_public': True,
#   'is_self_paced': True,
#   'is_unsuitable': False,
#   'issue': None,
#   'language': 'kk',
#   'last_deadline': None,
#   'last_step': '78-73048',
#   'learners_count': 7,
#   'learners_group': None,
#   'learning_format': '',
#   'lessons_count': 66,
#   'lti_consumer_key': '',
#   'lti_private_profile': False,
#   'lti_secret_key': '',
#   'moderators_group': None,
#   'options': {},
#   'owner': 140685666,
#   'peer_reviews_count': 0,
#   'position': 612,
#   'possible_type': None,
#   'price': None,
#   'price_tier': None,
#   'proctor_url': None,
#   'progress': None,
#   'quizzes_count': 637,
#   'readiness': 0.7,
#   'requirements': '\n    <p>5 математикасын орта деңгейде білу</p>\n\n  ',
#   'review_summary': 72596,
#   'schedule_link': None,
#   'schedule_long_link': None,
#   'schedule_type': 'self_paced',
#   'sections': [135253,
#    135254,
#    135255,
#    135256,
#    135257,
#    135258,
#    135259,
#    135260,
#    135261,
#    135262,
#    135264,
#    135273,
#    135266,
#    135267,
#    135268,
#    137328,
#    137329,
#    137330,
#    137331,
#    137332,
#    137333,
#    137334],
#   'slug': 'Логикаңды-дамыт-курсы-NEW-73048',
#   'social_providers': [],
#   'soft_deadline': None,
#   'soft_deadline_source': None,
#   'subscriptions': ['31-78-73048', '30-78-73048'],
#   'summary': '',
#   'tags': [],
#   'target_audience': 'КТЛ, НЗМ-ге дайындалуға арналған онлайн  курс',
#   'teachers_group': None,
#   'testers_group': None,
#   'time_to_complete': 15352,
#   'title': '"Логикаңды дамыт" курсы NEW',
#   'total_units': 66,
#   'update_date': '2020-06-17T08:27:28Z',
#   'videos_duration': 1367,
#   'workload': 'Күніне 50-100 минут жаттығу керек'},
#  {'acquired_assets': [],
#   'acquired_skills': [],
#   'actions': {'edit_advanced_settings': {'enabled': False,
#     'needs_permission': 'teach'},
#    'edit_lti': {'enabled': False, 'needs_permission': 'admin'},
#    'edit_reports': {'enabled': False, 'needs_permission': 'teach'},
#    'manage_permissions': {'enabled': False, 'needs_permission': 'admin'},
#    'view_grade_book': {'enabled': False, 'needs_permission': 'assist'},
#    'view_grade_book_page': {'enabled': False, 'needs_permission': 'assist'},
#    'view_reports': {'enabled': False, 'needs_permission': 'teach'}},
#   'admins_group': None,
#   'announcements': [],
#   'assistants_group': None,
#   'authors': [239058847],
#   'begin_date': '2020-05-31T22:36:36Z',
#   'begin_date_source': '2020-05-31T22:36:36Z',
#   'certificate': '',
#   'certificate_cover_org': None,
#   'certificate_distinction_link': None,
#   'certificate_distinction_threshold': None,
#   'certificate_footer': None,
#   'certificate_link': None,
#   'certificate_regular_link': None,
#   'certificate_regular_threshold': None,
#   'certificates_count': 0,
#   'challenges_count': 0,
#   'content_details': [],
#   'continue_url': '/course/73045/continue',
#   'course_format': '',
#   'course_type': 'basic',
#   'cover': '/media/cache/images/courses/73045/cover_LAxvQlG/b56ac603a5d2ffd5521f85f10f5853f2.jpeg',
#   'create_date': '2020-05-31T22:36:22Z',
#   'currency_code': None,
#   'description': '<p>Эпоксидная смола—универсальный материал, из которого можно сотворить что угодно и как угодно. Я предлагаю Вам попробовать сделать уникальный кулон!)\xa0</p>\n',
#   'difficulty': None,
#   'discussion_proxy': None,
#   'discussion_threads': [],
#   'discussions_count': 0,
#   'display_price': '-',
#   'end_date': None,
#   'end_date_source': None,
#   'enrollment': None,
#   'first_deadline': None,
#   'first_lesson': None,
#   'first_unit': None,
#   'grading_policy': 'no_deadlines',
#   'grading_policy_source': 'no_deadlines',
#   'hard_deadline': None,
#   'hard_deadline_source': None,
#   'has_tutors': False,
#   'id': 73045,
#   'instructor_reviews_count': 0,
#   'instructors': [239058847],
#   'intro': '',
#   'intro_video': None,
#   'is_active': True,
#   'is_adaptive': False,
#   'is_archived': False,
#   'is_censored': False,
#   'is_certificate_auto_issued': False,
#   'is_certificate_issued': False,
#   'is_certificate_with_score': False,
#   'is_contest': False,
#   'is_enabled': True,
#   'is_favorite': False,
#   'is_featured': False,
#   'is_idea_compatible': False,
#   'is_paid': False,
#   'is_popular': False,
#   'is_proctored': False,
#   'is_public': True,
#   'is_self_paced': True,
#   'is_unsuitable': False,
#   'issue': None,
#   'language': 'ru',
#   'last_deadline': None,
#   'last_step': '78-73045',
#   'learners_count': 2,
#   'learners_group': None,
#   'learning_format': '',
#   'lessons_count': 0,
#   'lti_consumer_key': '',
#   'lti_private_profile': False,
#   'lti_secret_key': '',
#   'moderators_group': None,
#   'options': {},
#   'owner': 239058847,
#   'peer_reviews_count': 0,
#   'position': 615,
#   'possible_type': None,
#   'price': None,
#   'price_tier': None,
#   'proctor_url': None,
#   'progress': None,
#   'quizzes_count': 0,
#   'readiness': 0.4,
#   'requirements': '',
#   'review_summary': 72593,
#   'schedule_link': None,
#   'schedule_long_link': None,
#   'schedule_type': 'self_paced',
#   'sections': [135197, 135198, 135199, 135200, 135201, 135202, 135203, 135300],
#   'slug': 'Кулоны-из-эпоксидной-смолы-73045',
#   'social_providers': [],
#   'soft_deadline': None,
#   'soft_deadline_source': None,
#   'subscriptions': ['31-78-73045', '30-78-73045'],
#   'summary': '',
#   'tags': [],
#   'target_audience': '',
#   'teachers_group': None,
#   'testers_group': None,
#   'time_to_complete': None,
#   'title': 'Кулоны из эпоксидной смолы',
#   'total_units': 0,
#   'update_date': '2020-06-02T05:28:20Z',
#   'videos_duration': 0,
#   'workload': ''}]

# %%
from tqdm import tqdm

# %%
rows = []
for page in tqdm(range(2,200)):
    try:
        data = json.loads(requests.get(url.format(page)).content)

        if not data['courses']:
            continue        
    
        for i in data['courses']:
            if i['language'] == 'ru':
                rows.append(i.values())
               
        if not data['meta']['has_next']:
            break
    except:
            print('some error')
# Out:
# 100%|██████████| 198/198 [02:48<00:00,  1.18it/s]

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=rows,columns=cols)

# %%
df
# Out:
#         id                                            summary  \
# 0    73761  Курс о том, как создать свой собственный искус...
# 1    73760
# 2    73756
# 3    73747  Курс, посвящённый базовым темам славянской и с...
# 4    73743
# ..     ...                                                ...
# 972  68690           Урок по теме "Металлы и сплавы" 5 класс
# 973  68689  В данном курсе разобраны прототипы 17 заданий ...
# 974  68688
# 975  68680  Курс ориентирован на дистанционное обучение шк...
# 976  68679
#
#                                          workload  \
# 0
# 1
# 2
# 3    Курс состоит из двух модулей и десяти уроков
# 4
# ..                                            ...
# 972                                             2
# 973
# 974
# 975                                            20
# 976                                 2 часа в день
#
#                                                  cover intro course_format  \
# 0    /media/cache/images/courses/73761/cover_FAYXSa...
# 1    /media/cache/images/courses/73760/cover_8rjhfu...
# 2                                                 None
# 3    /media/cache/images/courses/73747/cover_7TcjN6...
# 4                                                 None
# ..                                                 ...   ...           ...
# 972                                               None
# 973  /media/cache/images/courses/68689/cover_iOreKE...
# 974                                               None
# 975  /media/cache/images/courses/68680/cover_hobIpF...
# 976  /media/cache/images/courses/68679/cover_MRflFK...
#
#                                        target_audience certificate_footer  \
# 0                                         Все желающие               None
# 1                                                                    None
# 2                                                                    None
# 3                    Для тех, кому интересна мифология               None
# 4                                                                    None
# ..                                                 ...                ...
# 972                                                                  None
# 973                                            9 класс               None
# 974                                                                  None
# 975            Школьники 3-их классов начальной школы.               None
# 976  Учащиеся, сдающие ЕГЭ по профильной математике...               None
#
#     certificate_cover_org  is_certificate_issued  ...  moderators_group  \
# 0                    None                  False  ...              None
# 1                    None                  False  ...              None
# 2                    None                  False  ...              None
# 3                    None                  False  ...              None
# 4                    None                  False  ...              None
# ..                    ...                    ...  ...               ...
# 972                  None                  False  ...              None
# 973                  None                  False  ...              None
# 974                  None                  False  ...              None
# 975                  None                  False  ...              None
# 976                  None                  False  ...              None
#
#      assistants_group  teachers_group admins_group discussions_count  \
# 0                None            None         None                 0
# 1                None            None         None                 0
# 2                None            None         None                 0
# 3                None            None         None                 0
# 4                None            None         None                 0
# ..                ...             ...          ...               ...
# 972              None            None         None                 0
# 973              None            None         None                 0
# 974              None            None         None                 0
# 975              None            None         None                 0
# 976              None            None         None                 0
#
#     discussion_proxy discussion_threads lti_consumer_key  lti_secret_key  \
# 0               None                 []
# 1               None                 []
# 2               None                 []
# 3               None                 []
# 4               None                 []
# ..               ...                ...              ...             ...
# 972             None                 []
# 973             None                 []
# 974             None                 []
# 975             None                 []
# 976             None                 []
#
#     lti_private_profile
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ..                  ...
# 972               False
# 973               False
# 974               False
# 975               False
# 976               False
#
# [977 rows x 111 columns]

# %%
print(df.summary.values)
# Out:
# ['Курс о том, как создать свой собственный искусственный язык' '' ''
#  'Курс, посвящённый базовым темам славянской и скандинавской мифологии: устройство мира, божественная иерархия, мифические существа и их свойства'
#  ''
#  'Сжатый курс базовой немецкой грамматики для студентов А1-А2 для первичного ознакомления с языком и освоением базы для дальнейшего изучения.'
#  'Курс представляет собой систематизированное изложение основных проблем, включенных в лекционный курс экономики для студентов СПО'
#  'Курс включает в себя теоретическую и практическую части. Теоретическая часть Курса – это исчерпывающее, а главное – максимально доступное и понятное изложение исторических событий, явлений, фактов и описание деятельности исторических лиц с древности до наших дней. Практическая часть Курса включает в себя огромное множество заданий разного формата, решая которые, учащийся волей-неволей запоминает все необходимые факты.'
#  'Все великое - просто!' 'Самое важное о проведении теста Хи-квадрат в R'
#  '' '' ''
#  'Благодаря данному курсу вы научитесь использовать специальный пакет функций в R для поиска, публикации и кэширования данных.'
#  'Народные промыслы - время узнать немного больше или повторить изученое ранее!'
#  'Разведочный анализ данных в R с помощью пакета DataExplorer' ''
#  'Изучим 3 базовых времени в Английском языке: Present Simple, Past Simple, Future simple. Также познакомимся с глаголом to be. '
#  ''
#  'Данный краткий обзорный курс предназначен для знакомства с главными стадиями проектирования и реализации простейшего электронного устройства.\nОсновная часть курса посвящена разработке принципиальной схемы и печатной платы устройства "Светодиодная мигалка". Проектирование платы осуществляется в среде автоматизированного проектирования Altium Designer.\n\n'
#  '' ''
#  'Курс предназначен для дистанционного обучения\xa0математики шестиклассников за период четвертой четверти.'
#  '' '' ''
#  '            \n\nТрансляция опыта по достижению оптимальных (планируемых) результатов как показателя качества образования в условиях сельской школы\n\n\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \n\n\n\n\n\xa0 \xa0 '
#  'Курс по медиаграмотности от действующего журналиста. Поможет участникам лучше разбираться в информации, еждневно присутствующей в нашей жизни и не быть введенными в заблуждение. Предоставит способы создания качественных медиатекстов.    '
#  ''
#  'Теоретические положения о работе с грамматическими характеристиками в mystem, а также практические задания для отработки.'
#  'Данный курс содержит в себе информацию, которая Вам нужна для того, чтобы узнать что такое проектная деятельность '
#  'Первый шаг в теме анализа невербального поведения человека'
#  'Курс обучения предназначен для руководителей организаций, не отнесенных к категориям по гражданской обороне'
#  'Курс обучения предназначен для руководителей нештатных формирований по выполнению мероприятий гражданской обороны в организациях'
#  ''
#  'Курс направлен на развитие знаний, умений и навыков педагогов ДОУ в области художественно-эстетического развития детей 2-3 лет'
#  'Вы получите теоретические и практические знания по жостовской росписи (история, основные элементы, цвет...)'
#  'Коротко о курсе' 'Тьюториал по пакету sunburstR'
#  'Курс включает в себя теоретические и практические аспекты физического развития дошкольников. Знания закрепляются практическими заданиями и тестом. '
#  'Основы машинного обучения для 9 -11 классов' '' ''
#  'Подробный разбор прямой и\xa0косвенной\xa0речи\xa0в\xa0английском\xa0языке'
#  '' '' '' '' '' ''
#  'Курс создан для детей начальной школы, которые больше хотят узнать о попугаях.'
#  'Курс представляет собой теоретические и практические аспекты инклюзивного образования. Уровень знаний определяется с помощью заданий тестового и практического характера.'
#  'Сборник задач для развития навыков программирования\nВ курсе представлено несколько тематических разделов, каждый из которых содержит уроки. В каждом уроке предлагается\xa0несколько задач для решения.\xa0\xa0\n\nВсе задачи каждого урока дифференцированы от простых к сложным. Также предлагаются задачи повышенной сложности, которые помечены знаком "*".\n\nЧем больше звезд, тем выше сложность.'
#  '' '' ''
#  'Plans and Dreams (планы и мечты)\nОтработка конструкции "to be going to"\nУровень владения английским: Pre-intermediate\nВремя прохождения: 50 мин.\n\n'
#  ''
#  'В курсе вы сможете пройти тесты и узнать, на сколько вы осведомлены о теме правильного питания, похудения, набора мышечной массы. Также в курсе будет много полезной информации, касаемо похудения, набора мышечной массы и соблюдения ЗОЖ.'
#  '' '' '' 'Длинна названия курса 64 символа, максимально разрешенная.'
#  'Цель освоения программы «Латинский язык (основы фармацевтической терминологии)» - заложить основы терминологической компетенции специалистов – медиков, способных в своей практической и научной деятельности сознательно и грамотно пользоваться правилами выписывания рецептов и особенностями химической номенклатуры на латинском и русском языках.'
#  'Данный краткий обзорный курс предназначен для знакомства с работой современного станка с числовым программным управлением. Основная часть курса - программирование обработки шахматной фигуры "Ладья". Программирование осуществляется в системе ЧПУ Sinumerik. Начать программировать станок с ЧПУ - это просто!'
#  'Виртуальная реальность (virtual reality, VR) — это искусственный мир, созданный техническими средствами, взаимодействующий с человеком через его органы чувств.\nДополненная реальность (augmented reality, AR) частично погружает человека в виртуальный мир, когда на реальную картину мира накладывается дополнительная информация в виде различных виртуальных объектов. \nВ этом курсе вы познакомитесь с понятиями дополненная и виртуальная реальность, поработаете в программе Unity, попробуете создать свое мобильное приложение с дополненной реальностью и узнаете, как можно создать проект с виртуальной реальностью.'
#  'Простые шаги на пути к красивой речи.' '' '' ''
#  'На этом курсе Вы сможете сшить своими руками красивый, стильный, но при этом еще и универсальный жилет для прогулок.'
#  '' 'Все о growth hacking с практическими заданиями. '
#  'Курс основ графического дизайна, который позволит прокачать ваши компетенции. Вы легко сможете сделать отличную презентацию или разработать свой логотип.\nНОВАЦИЯ рождает ПРОГРЕСС'
#  '' '' '' '' '' '' '' ''
#  'Мастер-класс по 3D моделированию в системе Autodesk Fusion 360 от наставника компетенции "Инженерный дизайн CAD".'
#  '' ''
#  'Обучаем будущих разработчиков с нуля. 20 часов практики – бесплатно.\n\n'
#  'Курс включает в себя более 100 бесплатных уроков по программированию с нуля на платформе Xamarin.'
#  'Программа обучения "Обращение с отходами 1 - 4 класса опасности"\n\nКурс разработан в соответствии с программой профессиональной подготовки лиц на право работы с опасными отходами и предназначен для обучения и проверки знаний лиц, допущенных к обращению с отходами I-IV класса опасности.'
#  'Монтаж видео' '' '' ''
#  'Краткое обучение и ознакомление с компетенцией "Мобильная Робототехника", а так же сферами деятельности внутри неё. Если хотите узнать больше о нашей лаборатории и робототехнике, то вступайте в группу - https://vk.com/roboticslab'
#  ''
#  'Курс посвящен освоению базовых инструментов 3D редактора Blender. Курс является вводным и будет наиболее подходящим\xa0для слушателей, не имеющих опыта создания 3D моделей.'
#  'Курс объясняет как объединить графики в R с помощью пакета gridExtra' ''
#  '' ''
#  'Здесь будет протестированы ваши знания языка C++, которые необходимы для прохождения на второй модуль в нашем IT-квантуме! Ну и за одно вы сможете их подтянуть до нужного уровня, если таковым так и не овладели в период дистанционного обучения!'
#  '' '' '' ''
#  'Познавательно и кратко об истории театра. Занимательно и просто.'
#  'Курс обучения предназначен для руководителей групп занятий в организациях и на предприятиях различных форм собственности'
#  ''
#  'Курс позволяет протестировать бизнес гипотезы на стадии идеи. Основная цель - наименьшее количество затрачиваемых ресурсов и максимальная скорость.'
#  ''
#  'Курс обучения предназначен для работников, уполномоченных на решение задач в области гражданской обороны и защиты от чрезвычайных ситуаций в организациях'
#  ''
#  'Это Техника поможет вам тотально сконцетрироваться на нужной задачи и войти в ресурсное состояние'
#  'Главный герой - Светофор Светофорыч (СС). Он волшебный, и мы отправляемся с ним в путешествие, чтобы узнать почему его слушаются все: и машины, и пешеходы. А в течение месяца СС познакомит малыша еще и с воздушным и морским транспортом.'
#  'Главный герой - Светофор Светофорыч (СС). Он волшебный, и мы отправляемся с ним в путешествие, чтобы узнать почему его слушаются все: и машины, и пешеходы. А в течение месяца СС познакомит малыша еще и с воздушным и морским транспортом.'
#  'Главный герой - Светофор Светофорыч (СС). Он волшебный, и мы отправляемся с ним в путешествие, чтобы узнать почему его слушаются все: и машины, и пешеходы. А в течение месяца СС познакомит малыша еще и с воздушным и морским транспортом. \n'
#  'Развитие навыков и умений по разработке систем и обеспечению качества жизненного цикла электронных средств'
#  '' ''
#  'Курс погружает в теорию ограничений, помогая изучить книгу Э. Гольдратта и Д. Кокса "Цель. Процесс непрерывного улучшения".\n\nТеория ограничений  - популярная методология управления и непрерывных улучшений, которая позволяет решать проблемы и достигать целей в сложных ситуациях.\n\nКнига входит в библиотеку книг Сбербанка России.\n\n\n\n\n\n\n'
#  'об основах бюджетирования на русском и английском языках для всех, предпочитающих самостоятельно изучать материал'
#  'Курс по русскому языку за 7 класс для глухих и слабослышащих детей.\nСостоит из теоретического, практического материала. Представлены упражнения, тренинги, тесты.\n'
#  'В данном курсе ведется быстрая, но эффективная подготовка к ОГЭ по информатике. Рассматриваются алгоритмы выполнения заданий  и базовые понятия, необходимые для выполнения экзамена на 100%!\nКурс состоит из 3 модулей, последний который экзаменационный.'
#  ''
#  'Курс познакомит Вас с концепцией Интернета Вещей (Internet of Things, IoT) – устройств, объектов и сервисов, объединенных в глобальную сеть с интеллектуальными возможностями.'
#  'Курс рассчитан на студентов педагогических ВУЗов, учителей предметиков, которые хотят расширить свои знания в области организации образовательного процесса на основе системно-деятельностного подхода. '
#  '' 'Повторение лексики по теме "Дом".'
#  'Как лучше понять себя и достигать целей. Курс ориентирован на подростков и молодёжь и создан при поддержке Федерального агенства по делам молодёжи РФ в рамках проекта UNION'
#  'Данный курс предназначен для изучения основ проектирования игровой среды и для её программирования.\n\nКурс находится в тестовой разработке.'
#  'Решение задач для подготовки к всероссийской олимпиаде школьников.\nРассчитано, на школьников от 6 до 11 класса '
#  '' ''
#  'Привет и добро пожаловать в Green Country online! Мы здесь для того, чтобы Вы смогли разобраться в том, что же такое Past Simple, структуру этого времени, а также особенности его использования.'
#  ''
#  'Курс посвящен изучению технологии трёхмерного моделирования и по созданию чертежей, на примере программы Autodesk AutoCAD 2020.'
#  'Целями освоения данного курса являются: формирование комплекса компетенций в современных технологиях стратегического управления бизнесом. '
#  ''
#  'Интенсивное повторение первой части ЕГЭ по информатике. Два уровня сложности: базовый и продвинутый.'
#  'Практический онлайн-курс для тех, кто сталкивается в работе с однообразными повторяющимися операциями в Microsoft Excel и хочет автоматизировать их с помощью макросов на VBA.'
#  '' ''
#  'Курс посвящен изучению технологии трёхмерного моделирования и по созданию чертежей, на примере программы Solid Edge 2020.'
#  'Тестирования по основам робототехники и программирования на базе конструктора LEGO. Курс состоит из\xa0 15 вопросов, распределенных\xa0по темам, известным обучающимся на период прохождения тестирования.'
#  'Глаголы движения в русском языке.'
#  'Кто впервые использовал понятие вектор?\nГде в жизни можно встретить вектор?\nСхожи ли понятия "вектор на плоскости" и "вектор в пространстве"?\nА что будет с понятием "вектор " в n-мерном пространстве?\nОтветы на эти вопросы мы попробуем найти!\n"Верных вам направлений и правильно приложенных сил!"'
#  'Программа предусматривает поэтапную работу по развитию фонематических процессов, аналитико-синтетической деятельности, совершенствованию высших психических функций-созданию предпосылок для успешного овладения письменной речью.\n\n'
#  'Математика ( Параметр). Короткий видео урок который может быть полезен в старших классах.'
#  'Разбираем самые сложные задачи из ОГЭ и решаем их на раз-два!\nНебольшой видео разбор поможет разобраться с задачами и научиться их решать на автомате!'
#  'Курс "Марья-Искусница" поможет вам сделать первые шаги в мир народного творчества и научиться своими руками изготавливать замечательные сувениры из бисера и фетра.'
#  'Глаголы движения в русском языке.'
#  'The course is based on the "Enjoy English 8" book and represents an actual online version of one of the book\'s units to study from home. The final test is also included and, what\'s more, there are some task to give the students the idea of the OGE-exam coming for them next year.'
#  'Мини-курс включает один модуль, который состоит из двух уроков: "Столица России" и "Золотое кольцо России".'
#  'Теоретические основы и возможности функционирования глобальных систем бронирования и резервирования.'
#  'The course is intended for advanced training in programming machine tools with CNC system Sinumerik. He will teach you how to create flexible control programs for the manufacture of complex and precise parts on metal cutting machines, as well as manage these machines, turning them into your smart assistants.'
#  '' '' '' ''
#  'В этом курсе рассматриваются профессии, связанные с математикой и решение соответствующих задач.'
#  'Программа дистанционного курса предназначена для студентов СПО. Курс имеет практическую направленность и служит дополнением к основному курсу «Основы материаловедения».'
#  ''
#  'В курсе представлены произведения родной русской литературы для шестиклассников'
#  'Теория и практика по орфографии' ''
#  'Овладеть знаниями форматирования текстовых документов на компьютере и навыками работы в программе Microsoft Word.'
#  'Информатика.\xa0Углубленный уровень. 10 класс (4 часа в неделю)'
#  'Программа дистанционного курса предназначена для студентов СПО. Курс имеет практическую направленность и служит дополнением к основному курсу «Ручная дуговая сварка (наплавка, резка) плавящимся покрытым электродом».'
#  'Развитие навыков по созданию, оцениванию и сопровождению систем управление качеством радиоэлектронных средств'
#  'Тип дистанционного курса - освоение программного материала\xa0\n\n\u200cЦели - формирование предметных результатов, развитие различных аспектов мышления\n\n\u200cОсновная цель: Коррекция неуспеваемости на уроках математики\n\nВ данном дистанционном курсе основной упор делается на мотивацию в учебном процессе и развитие логического мышления.\xa0'
#  'Дистанционный семинар «Внедрение целевой модели цифровой образовательной среды в образовательных учреждениях Самарской области» (в рамках реализации федерального проекта «Цифровая образовательная среда»)»'
#  '' '' 'Мини-курс об основах турецкого языка.' ''
#  'Курс развивает у участников навыки гуманистики - изобретательства в гуманитарной сфере, научного воображения, творческих инноваций. Основные разделы посвящены становлению гуманитарных технологий в области философии, культурологии, лингвистики, литературоведения, а также взаимодействию гуманистики и техники.  Курс базируется на книге М. Эпштейна "От знания – к творчеству. Как гуманитарные науки могут изменять мир. "'
#  'В этом курсе несколько кратких, но ёмких глав из искусства развития мягких навыков, SoftSkills, иначе говоря, навыков для жизни.\nЦель курса - сделать так, чтобы у вас во владении оказался рабочий инструмент по управлению своим поведением и мышлением. А значит, по исполнению своих настоящих желаний.'
#  ''
#  'Информатика 6 -11 класс.               Беларусь.                                                        Курс рассчитан на IV четверть  для учащихся общеобразовательных учреждений образований.                               Уроки начинаются с 27 по 35. \nВозможно использовать как дополнительный материал на уроках и во внеурочной деятельности.                     \nТакже для удаленного обучения и дистанционного.\n'
#  '' '' '' '' '' '' '' 'Опирается на учебник Л.С.Атанасян' ''
#  'Знакомство с распознаванием объектов посредством языка программирования Python. В нём не нужны глубокие знания моделирования нейронных сетей.'
#  ''
#  'Мы живем в мире, где все очень быстро меняется и особенно цифровая сфера, в которой мы проводим уже порядка 80 % своего времени. И индустрия гостеприимства не исключение. Появление  конкурентов на рынке  и постоянный рост информационного пространства побуждает искать новые решения для ведения бизнеса. Тут на помощь приходят Информационные технологии. Наш курс и посвящен современным трендам ИТ в сфере туризма. \nЧто Вы узнаете: \nВлияние Интернет на индустрию гостеприимства. \nНовые тенденции развития ИТ в туризме: VR и AR – технологии и не только. \nПринципы работы автоматизированных систем управления:\nв гостинице: Opera Solution PMS, Epitome Systems PMS, - в ресторанном бизнесе - R-Keeper и Iiko – лидеры рынка.  \nКак с помощью «системы облаков» можно управлять фирмами в любой точке мира. \nСуществующие уровни автоматизации в туризме. \nКак связаны системы Интернет-бронирования и глобальные системы бронирования GDS. \nЧто же такое ГИС-системы. \nВзаимосвязь Маркетинговых и CRM-системы в индустрии.'
#  'Как проходит самое топовое событие среди инженерных команд. Что нужно знать прежде чем принять участие и как не оплошать в финале.'
#  'Промышленная (заводская) фармацевтическая технология.'
#  'Курс рассчитан на учеников "ГАОУ Лицей Иннополис"'
#  'Курс "Русский язык" предназначен для повторения разных разделов русского языка. Каждая отдельная \xa0тема\xa0содержит теоретический материал, видеоуроки, тест.\xa0'
#  '' '' ''
#  'дисциплина «Численные методы» принадлежит к общепрофессиональному циклу.'
#  ''
#  'Курс по робототехнике для тебя, \nесли тебе 12, 13, 14, 15, 16 лет\nПродолжай проектировать модели роботов \nИспользуй программу LEGO Digital Designer\nСконструируй робота из конструктора Lego\nСоздай свой проект, который можно представить на инженерный конкурс.'
#  'Курс по анатомии для студентов педагогического колледжа, в курс входит все темы прошедшие\xa0за год. Также подойдёт для тех кому нужно подготовится к егэ'
#  ' ТЕСТЫ ТЕСТЫ ТЕСТЫ ТЕСТЫ ТЕСТЫ ТЕСТЫ ТЕСТЫ ТЕСТЫ'
#  'Несмотря на\xa0то\xa0что\xa0квадрокоптеры крайне модная тема, выбирать компоненты для\xa0сборки своего аппарата по-прежнему не\xa0так просто. Выбор деталей для\xa0конкретного проекта\xa0— это мучительный поиск оптимального сочетания веса, мощности и\xa0функциональности. Поэтому прежде, давайте проделаем подготовительную работу.'
#  'Физическая культура для учащихся средней школы' '' ''
#  'Уроки музыки в 1 классе общеобразовательной школы. Программа Е.Д.Критской, Г.П.Сергеевой, Т.С.Шмагиной. '
#  'Курс для студентов, изучающих основы программирования на примере языка Си. \n\nДля прохождения курса рекомендуется иметь некоторую теоретическую базу, полученную на очных занятиях - большой блок заданий посвящён именно повторению изученного материала.\n\nПеред выполнением заданий рекомендовано внимательно читать формулировки и требования к вводу значений.'
#  'Уникальный проект "Продлёнка на удалёнке", созданный в условиях самоизоляции. Ежедневное планирование работы группы продленного дня в 1 классе.'
#  ''
#  'Курс  направлен на освоение знаний и умений в области методики организации различных видов продуктивной деятельности детей дошкольного возраста (рисования, лепки, аппликации, конструирования).'
#  'Курс по Web - программированию представляет собой серию уроков, объединенных в несколько разделов подкрепленных теоретическими и практическими заданиями.'
#  '' '' 'Курс лабораторных работ в среде MS Project'
#  'В курсе представлена информация о выражении предпочтения (Я люблю/Я не люблю), дается лексика по темам "Спорт", "Здоровье", "Еда". Курс на французском и русском языках.'
#  ''
#  'Курс нацелен на ознакомление с векторным редактором Method Draw, а также пояснение некоторых терминов векторной графики. Есть 2 поэтапного урока по созданию рисунка.'
#  '' ''
#  'Дистанционный курс "Тригонометрические уравнения и неравенства" нацелен на повышение мотивации у учащихся самостоятельно отвечать на возникшие вопросы, стремление успешно осваивать курс. '
#  'Информатика, как никакая другая область знаний, характе\xadризуется чрезвычайно высокой степенью динамики изменений. Кроме того, учитывая ее всепроникающий характер, благодаря которому происходит интеграция знаний, идей, в настоящее время трудно очертить границы информатики. Удается выде\xadлить лишь ее основные направления.'
#  'Изучение методов и технологий промышленного дизайна на примере программного обеспечения Autodesk AutoCad'
#  '' 'Грамматика'
#  'Цикл занятий "Скорочтение и развитие памяти" - это авторская система внедрения\xa0способов быстрого чтения в обычную жизнь и тренировки\xa0\xa0памяти, внимания, мышления.\xa0\nЗанятия разбиты на ступени. Каждая ступень логично продолжает следующую.\nЗанимается каждый в комфортном для него темпе. '
#  'Раздел алгоритмизация и программирование в школе. \nК учебнику  Полякова К.Ю. 10 класс 2 часть. В курсе представлены задания с возможностью проверки решения.'
#  ''
#  'Данный курс поможет вам освоить тему "Имя числительное".\xa0\n\nОн состоит из уроков, а уроки - из шагов.\n\nКаждый урок начинает с теоретических шагов:\xa0\xa0вы сможете посмотреть видео-урок и прочитать правила. После этого начнется практический этап. Шаги на этом этапе будут содержать вопросы и задания, которые проверят уровень усвоенного материала.\xa0\n\nВо время прохождения урока у вас будет возможность вернуться к теоретическим шагам, чтобы еще раз прочитать правила или посмотреть видео-урок. А также можно будет вернуться к любому\xa0из предыдущих шагов, если вы сразу не справитесь с заданием.\xa0'
#  'Курс для дистанционного обучения программированию учеников 11 класса школы 1368'
#  ' Задания для самостоятельной работы'
#  'Итоговая контрольная работа по тригонометрии. Работа рассчитана на 90- 120 минут.'
#  'Учиться, учиться и ещё раз учиться!'
#  'Курс "Введение в дистанционное обучение" предназначен для педагогов МБУДО "Центр внешкольной работы "Галактика" и проводится в рамках Школы профессионального роста педагога.'
#  'Курс для учащихся Медиашколы "Спутник" ЦВР "Галактика"'
#  'Модуль «Открываем мир природы» имеет естественнонаучную направленность, расширяет знания учащихся об окружающем мире, способствует развитию интереса к изучению природы'
#  'Данный курс опирается на знания и навыки, которые дает  основное общее школьное образование. Будет полезен студентам, учащимся школ и всех, кто хочет вспомнить биологию.'
#  'Контрольная работа №9.' '' '' '' ''
#  'Курс направлен на приобретение обучающимися компетенций цифровой экономики, лежащих в основе современных технологий проектирования химического оборудования, а также может способствовать дальнейшей профессиональной ориентации.'
#  'Данный курс поможет освоить базовые компетенции в области виртуального проектирования, схемотехники и программирования контроллера Arduino'
#  'Курс посвящен изучению основ алгоритмизации и программирования на примере исполнителя Черепаха, входящего в состав комплекта учебных миров (Кумир).'
#  'Вы уже не новичок в Excel, но есть понимание:\xa0"Мою работу точно можно упростить и ускорить!"  Перестанете бегать с вопросами к знакомым "гуру Excel".'
#  'курс крутой, реально. заходите, решайте, готовьтесь)'
#  'Дополнительная общеразвивающая программа «Мир исследователя» имеет естественнонаучную направленность, формирует знания о природе, устанавливает отношение к проблемам экологии, и развивает умения рационального природопользования. Овладение экологическими понятиями - главный путь вооружения обучающихся основами экологии.'
#  'Курс научит Вас электронике, программированию микроконтроллера Arduino на c++, созданию мобильных роботов. '
#  'Курс посвящен изучению технологии трёхмерного моделирования и по созданию чертежей, на примере программы Autodesk Inventor 2016.'
#  'Этот курс создан для дистанционного обучения студентов АПО ВО "Устюженский политехнический техникум". По сути - это пары по дисциплине "Русский язык" для 211, 511, 421 и 621 групп техникума.'
#  'Курс предназначен для ребят, проходящих обучение на базовых и углубленных программах в Детском технопарке Кванториум по направлению БИО.\xa0'
#  'Дополнительная общеразвивающая программа «Мир исследователя» имеет естественнонаучную направленность, формирует знания о природе, устанавливает отношение к проблемам экологии, и развивает умения рационального природопользования. Овладение экологическими понятиями - главный путь вооружения обучающихся основами экологии.'
#  'Курс для тех, кто хочет прокачаться в Excel за минимальный срок, решая задачи, максимально приближенные к боевым.'
#  'За 10 дней практики стань эффективным сотрудником на удаленке.' ''
#  'Наш курс рассчитан для новичков, мастеров с небольшим опытом работы, желающих освоить технику комбинированного и аппаратного маникюра. Научиться правильно выполнять покрытие гель-лак .'
#  'Урок по теме "Металлы и сплавы" 5 класс '
#  'В данном курсе разобраны прототипы 17 заданий  ОГЭ.' ''
#  'Курс ориентирован на дистанционное обучение школьников 3-их классов.' '']

# %%
print(df.title.values)
# Out:
# ['Искусственные языки и зачем они нужны' 'Роза'
#  'Базовые операторы, ветвление и циклы в языке Python'
#  'Введение в мифологию. Скандинавские и славянские мифы'
#  'История Второй Мировой' 'Немецкий язык для начинающих'
#  'Основы экономической теории' 'Подготовка к ОГЭ по истории'
#  'Практическая педагогика' 'Детям о животных'
#  'На какой платформе писать сайт?' 'Formattable in R'
#  'математика егэ профиль' 'Базы данных' 'Квиллинг' 'Всё о кошках'
#  'Домашние животные' 'WorldSkills Russia Juniors LabChemAnalysis' '1'
#  'Основы кибербезопасности' 'Системы счисления'
#  'Риторика делового общения.' 'English grammar ' 'Естествознание'
#  'Отбор | ШОП по математике Университета Иннополис |  10 класс'
#  'Отбор | ШОП по математике Университета Иннополис |  11 класс' 'Клетка'
#  'Учимся работать с Microsoft Office Word 2003' 'Задачи'
#  'Базовый курс по созданию простых игр на Unreal Engine 4'
#  'Ингмар Бергман как пример метафизического кинематографа'
#  'Основы дизайна'
#  'Методика использования систем компьютерной графики при обучении '
#  'Фармакология' 'Безопасность школьников в интернет-пространстве'
#  'T-test и тест Манн-Уитни и визуализация в ggpubr'
#  'Django REST Framework на практике' 'leçon de français' 'Рисунок'
#  'Технология разработки интернет-приложений' 'Изобразительное искусство'
#  'Python: разработка Telegram-бота' 'Python: для начинающих программистов'
#  'Циклы в R' 'Нейрофилософия' 'Птицы' 'Птицы' 'my course'
#  'Историко-педагогическая компетентность.' 'Астрономия для начинающих'
#  'Тест хи-квадрат: визуализация, интерпретация и примеры'
#  'Rainbow English-5' 'Тестовый курс' 'Изобразительное искусство'
#  'Pins in R' 'Народные промыслы' 'DataExplorer'
#  'Технология обработки древесины. Элементы машиноведения.'
#  'Simple English' 'узнаём танки'
#  'Технические лаборатории СФТИ НИЯУ МИФИ - Электроника' 'Spelling hack'
#  'Окружающий мир.  Насекомые' 'Copy of Математика для шестиклассника '
#  'test invitation link' 'Умение налить себе воды' 'Test'
#  'Региональная стажировочная площадка МКОУ "Уянская СОШ" '
#  'Медиаграмотность и критическое мышление' 'Готика'
#  'Определение грамматических характеристик в mystem'
#  'Основы проектной деятельности' 'Copy of Искусство чтения человека'
#  ' Курс обучения для руководителей организаций'
#  'Курс обучения для руководителей НФГО' 'Помыть яблоко'
#  'Художественно-эстетическое развитие детей 2-3 лет ' 'Жостовская роспись'
#  'Информатика БиТ - 7 класс'
#  'Визуализация иерархии и вложенности с sunburstR'
#  'Физическое развитие детей дошкольного возраста'
#  'Основы машинного обучения' 'Цифровая грамотность (Группа 2)'
#  'Цифровая грамотность (Группа 1)' 'Reported speech' 'Обж для чайников'
#  'Итоговый зачёт по дисциплине "Теоретические основы химии"'
#  'Финал Интеллектуальные АНПА Innopolis Open 2020' 'Секреты манипуляции'
#  'Курс накрутка баллов 1735' '"Электроника негіздері"' 'Мир попугаев'
#  'Инклюзивное образование в системе ДОУ ' 'Решение задач'
#  'Интерактивная визуализация с ggiraph'
#  'Тезнология Создания Geometry Dash уровней' 'Бихевиоризм'
#  'Plans and Dreams'
#  'Отбор | ШОП по математике Университета Иннополис |  7-9 класс'
#  'В здоровом теле - здоровый дух!'
#  'Технологии уборка в медицинских организациях'
#  'Статистические тесты на сетях' 'Английский язык'
#  'Самое длинное и странное название холма в мире, в Новой Зеландии'
#  'Английский в песнях' 'Курс работы с текстовым редактором Microsoft Word'
#  'Как научиться рисовать?'
#  'Математические основы информатики. С нуля до профессионала'
#  'Царства живой природы' 'Музыка барокко'
#  'Тренинг курс для специалистов по работе с молодёжью' 'elbook'
#  'Коммуникативная безопасность' 'Техническое черчение' 'Функция'
#  'История дошкольной педагогики' 'русский язык'
#  'Орнамент. Основы орнаментации.'
#  'Как обсудить темы безопасности с ребенком'
#  'Интерактивная визуализация с plotly' 'Земноводные, или Амфибии'
#  'Основы рисования' 'GoTo Test 2020' 'Класс Рыбы'
#  'Разработка приложений для решения прикладных задач на языке VBA'
#  'Copy of Рыбы'
#  'Методика застосування інформаційних технологій в навч. закладі'
#  'Энергосбережение и климат: для детей и взрослых' 'Copy of тестовый курс'
#  'Современный детский сад: мы на стороне ребенка.'
#  'Кое-что о современном театре' 'Многоугольники' 'Информатика 8 класс'
#  'Структуры данных и попытки их реализации С++' 'Курс 1'
#  'Нескучный дистант ' 'Знакомство с образовательным конструктором Lego'
#  'Алгебра  7 класс УМК А.Г. Мерзляк' 'Кулоны из эпоксидной смолы'
#  'ЭКОЛОГИЯЛЫҚ ПӘНДЕРДІ ОҚЫТУДЫҢ ӘДІСТЕРІ' 'ИИПК' 'Online Курс'
#  'Экологический мониторинг' 'Гейм-дизайн' 'БЕЗОПАСНОСТЬ ЖИЗНЕДЕЯТЕЛЬНОСТИ'
#  'Экологические аспекты токсичности и мутагенеза пестицидов и ТМ'
#  'Баланс белого (WB) ' 'Основы HTML' 'информатика 1 курс'
#  'Как приготовить яблочно-брусничный пирог' 'HTML для начинающих'
#  '«Современные компьютерные угрозы и кибербезопасность»'
#  'Астрономия. С нуля до профессионала' 'Технология электромонтажных работ'
#  'Прыжки в фигурном катании' 'astrology' 'Онлайн школа'
#  'Подготовка к ОГЭ по математике ' 'Мини-курс "Кварц"' 'БИОГЕОЦЕНОЗ'
#  'Импрессионизм ' 'Жанры аниме и манги'
#  'Профилактика при помощи ТСР вторичных нарушений у детей с ДЦП'
#  'Copy of МедиаГИД' 'Общий деловой английский'
#  'Полный базовый курс по произношению на английском языке'
#  'Ерундопель из галлицизмов' 'Курс-Тест' 'Живопись'
#  'Школа вожатых Приморского края 2020' 'Физическая культура '
#  'Роспись на джинсах' 'Python для начинающих'
#  'Современный европейский театр' 'Вводный модуль IT-квантум'
#  'Олимпийские игры' 'Работа в программе Паинт Paint ' 'Уборка в шкафу'
#  'Изобразительно-выразительные средства в литературе'
#  'Брауни с щепоткой филологии' 'Акриловая живопись '
#  'Новая цифровая реальность: цифровые двойники изменят нашу жизнь?'
#  'Облачные технологии для задач цифровой экономики'
#  'Простые программы и основы вычислений на языке Python'
#  '«Оператор электронно-вычислительных и вычислительных машин»'
#  'Зоопсихология. Сертификат.'
#  'Связи с общественностью: новейшие коммуникационные технологии'
#  'Логотерапия: представление о человеке. Сертификат'
#  'Биотех: AI в медицине' 'Цифровые данные' 'Эволюция технологий и людей'
#  'Инженерный дизайн (Рябицев А.С. ГАОУ АО ДО "РШТ")'
#  'Основы и полезные приёмы работы с диаграммами в Excel'
#  'Все секреты ВПР в Excel' 'Сводные таблицы в Excel'
#  'Продвинутые формулы и инструменты в Excel'
#  'Подготовка к ЕГЭ по информатике'
#  'Основы рыночной экономики и предпринимательства'
#  'Основы духовно-нравственной культуры народов России (5 класс)'
#  'Подготовка к олимпиадам' 'Реклама и связи с общественностью' '131'
#  'Игра го. Уровень: стартовый' 'ОСНОВЫ РЕКЛАМЫ И СВЯЗИ С ОБЩЕСТВЕННОСТЬЮ'
#  'Электронное учебное пособие "Первые шаги по созданию сайта"'
#  'Английский для дошкольников' 'Филолог в естественной среде обитания'
#  'Домашние животные. Собаки.' 'Администратор салона красоты'
#  'UX-стратегия разработки приложений. Исследование пользователей.'
#  'Реклама и связи с общественностью' 'Многочлены 7 класс'
#  '"Информатика 1-4"' 'География' 'Ядерная физика-просто!' 'Test'
#  'Физическая культура Дробок' 'Вводный модуль ПРОМДИЗАЙНКВАНТУМ'
#  '"Моя вторая профессия - 2020". Вожатый.' 'Вводный модуль РОБОКВАНТУМ'
#  'Сказка "Гадкий утёнок"'
#  'Публикационный процесс от и до - руководство для молодых ученых'
#  'Обучающий курс по теме "Информация"' 'Логопедия'
#  'Греко-римская и вольная борьба ' 'Пожарно-технический минимум'
#  'Латинский язык (Основы фармацевтической терминологии)'
#  'Знакомство с работой токарного станка с ЧПУ. Изготовление шахмат'
#  'Вводный модуль VR/AR-квантум' 'Техника речи' 'Волейбол' '8' 'Космос'
#  'Создание жилета. Пошаговая инструкция.' 'Здоровый образ жизни '
#  'Growth Hacking в России' 'Adobe Illustrator: первые шаги'
#  'Пишем новый яп' 'Весенняя олимпиада по РТ для 8т' 'Заочное отделение 5а'
#  'Контрольные работы по математике' 'Строение  атома.Химическая связь.'
#  'Туризм в школе' 'BrainSkills-test' 'Тест'
#  'Технические лаборатории СФТИ НИЯУ МИФИ - Инженерный дизайн CAD'
#  'впарварар' 'Курс по SQL-Transact для новичков' 'Создание сайтов с нуля'
#  'Руководство по программированию для Xamarin Forms'
#  'Экологическая безопасность ( отходы I-IV класса опасности).'
#  'Обработка и монтаж видео на телефоне!' 'Математика 3 класс'
#  'Здоровый образ жизни ' 'Английский язык' 'Мобильная Робототехника'
#  'Импрессионизм в живописи' 'Основы 3D моделирования в Blender'
#  'Объединение графиков: gridExtra в R' 'Животные' 'Экзамен'
#  'Весенняя олимпиада по РТ  '
#  'Тест знаний языка C++ IT-квантум Южно-Сахалинск'
#  'Литературное редактирование' 'Рыбы' 'Рыбы' 'Лыжный спорт'
#  'История театра' 'Курс обучения для руководителей групп занятий'
#  'особенности реализации государственной языковой политики:вопросы'
#  'HADI-цикл тестирования бизнес идеи для стартапа'
#  'Туризм для школьников '
#  'Курс обучения для работников, уполномоченных по ГО и ЧС'
#  'Весенняя олимпиада по РТ для 5с' 'Техника "Сожжение Мысли"'
#  'Основы электротехники' 'Солнечная система' 'Искусство '
#  'Стратегия общения с особенным ребенком: кризис "3 лет" '
#  'Изобразительное искусство' 'Программирование на Python. Часть 2'
#  'Собака - друг человека' 'Живопись' 'Regular expressions'
#  'Обобщение и систематизация знаний учащихся 9 класса АЛГЕБРА'
#  'Быстрый старт! | ¡Rápido! | Испанский язык'
#  'Художка - это моя жизнь, черт подери'
#  'Разработка умного дома на платформе "Arduino"' 'Тест Python'
#  'Тест Ардуино' 'Отработка навыков ухода'
#  'УП 01.01 Обработка отраслевой информации' 'Постимпрессионизм '
#  'Начальная школа ' 'ИЗО' 'Открытый урок 7-8'
#  'Углубленный курс алгебры 7 класса'
#  'Экзамен по дисциплине "Теоретические основы химии"' '1С: Бухгалтерия'
#  'Прямой отбор на Интеллектуальные АНПА Innopolis Open 2020'
#  'Открытый урок 6 класс' 'Введение в 3D моделирование'
#  'Математика огэ 2021' 'Интегралы (для программистов)' 'Инфокурс'
#  'paid course 1 rub' 'Квест для семиклассников по робототехнике май  2020'
#  'Рыбы' 'Контрольные и проверочные работы'
#  'Игровые занятия для детей 4-5 лет (Demo)'
#  'Формирование речевого слуха, 4 класс'
#  'Термодинамика. С нуля до профессионала.'
#  'Российское образование в XVII-XIX веках' 'd' 'Русские художники'
#  'Экспресс Pascal' 'BuildSims4' 'Уроки программирования на С++'
#  'Программирование на C++' 'Курс ReactJS'
#  'ТЕХНОЛОГИИ РАЗРАБОТКИ ИНТЕРНЕТ-ПРИЛОЖЕНИЙ' 'Проба(-_-)' 'виды молотков'
#  'Copy of Программирование на Python [Sanak-lab 2019/20]'
#  'Устройство государств, обществ и культур в сырьевых экономиках'
#  'Готовим кофе дома' 'Моделирование'
#  'Copy of Информатика и ИКТ в профессиональной деятельности '
#  'Русский язык для бизнеса'
#  'Мини-курс повышения квалификации "Электронные средства обучения"'
#  'Химия 8 класс' 'Углубленный курс физики 8 класса'
#  'Голосеменные растения' 'Летний практикум' 'Докторская диссертация'
#  'Как украсть сотку ' 'ЕГЭ 27 задания на Python'
#  'Русский язык и литература' 'Пожар' 'Environmental Issues' 'Птицы '
#  'Пушкин наше всё!'
#  'Подготовка к межшкольной комплексной олимпиаде по биологии 1502'
#  'Трехмерное моделирование в Autodesk AutoCAD'
#  'Английский для программистов (TOP-500 IT words)'
#  'Робототехника тестирование 2 год '
#  'Медицинский колл-центр: как работать с возражениями пациентов'
#  'Мысли в пространстве.'
#  'Изучение процентов через задачи с историческим содержанием'
#  'Задачи Олимпиады ОКДНТИ (2019-2020гг)'
#  'курс обучения для Председателей (членов) комиссии по ЧС и ОПБ'
#  'English Grammar' 'Путешествия со Светофор-Светофорычем 5-6'
#  'Путешествия со Светофор-Светофорычем 4-5'
#  'Путешествия со Светофор-Светофорычем 3-4'
#  'Путешествия со Светофор-Светофорычем 2-3'
#  'Системы обеспечения качества жизненного цикла ЭС' 'Тестовый'
#  'Углубленный курс физики. 1 часть'
#  'Как улучшить управление организацией? Изучаем книги Сбербанка.'
#  'Бюджетирование. Просто о сложном' 'Русский язык 7 класс'
#  'Экспресс подготовка к ОГЭ по информатике. 2021 год' 'Курс1'
#  'Введение в Интернет Вещей'
#  'Теоретические основы  реализации системнодеятельностного подхода'
#  'Урок "101"' 'Мой дом - моя крепость' 'Психология саморазвития'
#  'Введение в игровую индустрию(GameDev)' 'Олимпиада 2020'
#  'Особенности временного детского коллектива' 'Сериалы'
#  'Past (is so) Simple' 'Инфраструктура туризма.'
#  'AutoCAD 2020, основы трёхмерного моделирования'
#  'Система сбалансированных показателей в управлении эф-тью бизнеса'
#  'Создание 3D моделей' 'ИНТЕНСИВ ЕГЭ 2020 информатика'
#  'Макросы в Excel для новичков' 'Литература' 'фтзика для чайников'
#  'Solid Edge 2020, основы трёхмерного моделирования'
#  'Робототехника тестирование 1 год ' 'Идём или едем?'
#  'Интересное о векторах.'
#  'Преодоление фонетико-фонематических трудностей у первоклассников'
#  'Математика' 'Математика ОГЭ - разбираем самые сложные задания (1-5)'
#  'Марья-Искусница' 'Идём или едем?' "It's a wonderful planet we live on."
#  'Путешествие по России'
#  ' Глобальные системы бронирования и резервирования'
#  'Sinumerik: advanced programming'
#  'Преодоление фонетико-фонематических трудностей у первоклассников'
#  'Математика 9' 'Программирование Scratch ' 'педагоги оо'
#  'Математика в профессиях' 'Маркировка сталей' 'Литература'
#  'Родная русская литература 6 класс' 'Русский язык без репетитора'
#  'Введение в органическую химию' 'Форматирование текста'
#  'ЭОР по информатике' 'Условное обозначение сварочных электродов'
#  'Системы управления качеством РЭС и их сопровождение'
#  '"Будни управляющего"' '"Цифра в школе" VS. "Школа в цифре" (1.0)'
#  'Мини-курс по русскому языку как иностранному' 'Фармакология'
#  'Турецкий язык: вводный мини-курс' 'Физика, 8 класс'
#  'Инновации и изобретательство: как от знаний перейти к творчеству'
#  'Информатика с ЕВ' 'турецкий для Вари' 'Модальные глаголы'
#  'Русский язык для новичков' 'Создание графического редактора на python'
#  'Машинное обучение и управление проектами в IT для преподавателей' 'РАО'
#  'Английский по Skype' 'География 7 сынып '
#  'Признаки равенства треугольников. Геометрия 7 класс'
#  'Copy of Решение уравнений и неравенств'
#  'Instagram-маркетолог:\xa0ведение и продвижение\xa0бизнес-аккаунта'
#  'Зачет по программированию на Python' 'Samsung IT School Очный этап'
#  'Как создать стартап' '6 класс тематический контроль' 'Углы и диаграммы'
#  '5 клас тэматычны кантроль' 'Производная ' 'Эволюция живой природы (ЕГЭ)'
#  'Лёгкий старт в робототехнику [Диченко М.Ю.]'
#  'Математика: алгебра, начала математического анализа, геометрия'
#  'Уроки технологий Аэро ' 'Курс молодого бойца online'
#  'Обучение официанта' 'Copy of Подготовка к ВПР (1) физика 7 класс 2020 '
#  'Введение в индустрию VR' 'Подготовка к ОГЭ по математике'
#  'Начало математического анализа / 10-11 кл.'
#  '"Моя вторая профессия - 2020". Воспитатель.' 'Инновации в туризме'
#  'Инновации в туризме' 'Academic foreign language (test)'
#  'Олимпиадная Математика' 'Онлайн-школа Dota 2' 'Базовые знания кондитера'
#  'Решение уравнений и неравенств' 'Медиа точка'
#  'Работа с демоверсией iStom ' 'Умножение и деление десятичных дробей'
#  'Подготовка к ЕГЭ по русскому языку' 'Юля Развитие мышления '
#  'Эконометрия 2020 NSU' 'Обучение наставников' 'Школа' 'Основы искусства'
#  'Basic_Test' 'ЕГЭ английский, задания 19-25' 'Всё о Норвегии'
#  'Геометрия 10 класс. Май' 'Теоретическая механика'
#  'Местоимение как часть речи' 'Алгоритмизация и программирование 10 класс'
#  'История' 'Познание лошадей' 'Экспресс подготовка к ОГЭ информатика 2020'
#  'рисование' 'экспресс подготовка к огэ информатика 2020' 'физика впр 8'
#  'Изобразительная деятельность' 'Онлайн тур 27.04.2020'
#  'Матигра 25.04.2020' 'Flask mini – вводный курс' 'ПАРИКМАХЕР-УНИВЕРСАЛ'
#  'StartIT - Развитие мышления '
#  'Растительная клетка - что это?Основы ботаники.'
#  'Теория и методика ФЭМП у детей' 'Модальные глаголы'
#  'События Великой Отечественной войны в литературе XX века'
#  'ЗНАКОМСТВО С ВЕДАМИ'
#  'Моделирование и подготовка к 3D-печати в системе T-FLEX CAD'
#  'Значение имён  ' 'Классификация неорганических веществ'
#  'Программирование на Python' 'Основы работы в Redash (часть 1)'
#  'Физика 8 класс' 'Контрольная работа Физика 10 класс '
#  'Физические методы исследования материалов ' 'Справочные материалы '
#  'Геометрия для семиклассников'
#  'Серия вебинаров о\xa0разработке ПО для ОС\xa0Аврора (20.04.2020)'
#  'Ключи от Доброго Углича' 'НАНО '
#  'Инженерный экзамен "Инжинириум". Программирование C++. День 2-й'
#  'Квантошахматы Балашиха' 'AEROквантум' 'ehjr'
#  '4 класс Теоретический материал уроков ' 'Инфографика для начинающих'
#  'Урок технологии (школа 1540) Преподаватель Диченко М.Ю'
#  'Основы языка программирования Python'
#  'Основы SCM (управление цепями поставок)'
#  '1 класс. Теоретический материал уроков' 'Проценты' 'Веселый Русский  '
#  'Подготовка к ЕГЭ по математике(2ая часть).'
#  'Дистанционный курс по математике для 10 класса' 'Старт в Билайн'
#  'Основные понятия и законы химии. 8-9 класс средней школы'
#  '10 ЗАКОНОВ ДЕНЕГ' 'Пробный. Геометрия 10 класс' 'Шахматы. Школа 585'
#  'python' 'Основы аналитического чтения на уроках английского языка'
#  'Power Query в Excel' 'Русский язык. Подготовка к ОГЭ'
#  'Жанры публицистики. Портретный очерк' 'Органическая химия'
#  'Формула образования. Школа: ученик, родитель, учитель.'
#  'Дхарма и Буддизм: Как научиться Медитировать.'
#  'Тренировочный тест для поступления на ПМИ в питерской Вышке'
#  'Правельное поведение в сети интернет.' 'ютуб создать канал'
#  'ЕГЭ по русскому языку' 'ИБб-16 Контрольный тест по дисциплине ОУИБ №2'
#  'Русский язык: Просто про слова' 'Игровые занятия для детей 1-2 года'
#  'ИБб-16 Контрольный тест по дисциплине ОУИБ №1'
#  'DS2019 - Статистическая информация в графиках с ggstatsplot'
#  'Digital Humanities' 'Анализ данных в социальных науках'
#  'Экологические основы природопользования'
#  'КОМПАС-3D v18, (продвинутый уровень)' 'Copy of Местоимение'
#  'ЕГЭ по русскому: нормальные варианты' 'Криптография и котики'
#  'Copy of ОНТИ 18/19. Автономные транспортные системы. Этап 2.'
#  'Copy of Олимпиада КД НТИ 19/20. Этап 2. Летательная робототехник'
#  'Поэзии посвящается...' 'ENGLISH 2 course' 'Свободное погружение в СУБД'
#  'Our favourite English 3 (for third-year students) '
#  'Our favourite English 2 (for second-year students)'
#  'Дизайн инфографики и визуализации данных' 'Цветоведение'
#  'Обществознание 10 класс' 'Грамматика Английского Языка'
#  '#Подключаембизнес' 'Тестирование по дисциплине "Охрана труда"'
#  'YouTube для бизнеса. Как продвигать бизнес через канал.'
#  'Программирование АНПА (в рамках IOR)'
#  'Логарифмы из 1 части ЕГЭ по профильной математике'
#  'Математика для семиклассника ' 'Программируем Arduino'
#  ' Технология домашнего хозяйства. 1 часть' 'Астрономия'
#  'Makeup Basics for Beginners' 'Сборка и запуск программ'
#  'Технологии композитов 2120'
#  'Необычная журналистика "Уникальный репортёр"'
#  'Инженерный экзамен "Инжинириум". Композитные технологии'
#  'Еда в дополненной реальности (AR)' 'Игровые занятия для детей 5-6 лет'
#  'Инженерный экзамен "Инжинириум". Трёхмерные технологии'
#  'Решение задач открытого типа в группе - вводный курс'
#  'Устройство компьютера' 'Инженерный экзамен "Инжинириум". Робототехника'
#  'Инженерный экзамен "Инжинириум". Программирование C++'
#  'Как набрать и адаптировать команду удаленщиков в отдел продаж'
#  'немного о 1968 в истории США'
#  'Физическая культура, Ореховская СОШ, 2020.'
#  'Обучение С++ (Решение задач)'
#  'Всеобщая история .История  Нового времени 8 класс.'
#  'Неизвестные кампании РККА'
#  'Copy of Защита информации. Шифрование данных' 'Трудовое право' 'English'
#  'Леттеринг ' 'Time management: how to learn manage your time?'
#  'Физика 10' 'Электрохимические методы анализа'
#  'Текстовые задачи по математике'
#  'Инструментарий администратора информационных ресурсов'
#  'Игровые занятия для детей 4-5 лет' 'Игровые занятия для детей 3-4 года'
#  'initiation into memologues' 'geography'
#  'Methods and factors of survival in extreme conditions'
#  'информатика 10 класс' 'ICT' 'Физическая Гостиная' 'ghyjkj'
#  'English/polyglot' 'Проверь себя. Как играть эндшпиль?' 'Алгебра 7 клас'
#  'IT' 'тренажер цифровых компетенций' 'Беларуская мова 5 клас'
#  'Дистанционный курс по алгебре для 8 класса' 'History of Kazakhstan'
#  'информатика 11 класс' 'Профориентация 9 класс'
#  'Кризисный менеджмент для НКО: обживаем новый мир'
#  'Немецкий язык: общий курс.' 'Проектная смена. Экология.'
#  'COOKING SWEETS FOR BEGINNERS' 'Практика осознанности. Большой курс'
#  'История Средних веков.' 'What to do at home during quarantine?   '
#  'SolidWorks, основы трёхмерного моделирования' 'Вторая мировая война'
#  'Preparation for Unified National Testing' 'Проектное финансирование'
#  'Цифровая обработка изображений в редакторе Photoshop'
#  'Обществознание. Повторение.' 'Elementary school '
#  'how to earn money in eSports!' 'Обучающий курс по онлайн фотошоп.'
#  '"Something original"' 'The passive voice' 'Математика в картинках.'
#  'Copy of Как стать успешным дистанционным преподавателем'
#  'Copy of Cooking with Arai' 'Admin iceDay' 'Cooking with Arai'
#  'French cuisine' 'History of music'
#  'Введение в специальность промышленный альпинизм'
#  'How\xa0to start\xa0cooking healthy meals\xa0at home?'
#  'Творчество русских композиторов.' 'Taking IELTS'
#  'ЕГЭ, Математика + Информатика (+80)' 'World Religion'
#  'Как организовать обучение информатике и математике слепых детей'
#  'Основы Python и сбор открытых данных' 'Designer' 'Тапик' 'Информатика'
#  'Дата-журналистика' 'Mythology' ' World economy'
#  'Their business -  Restaurant' 'Rock Guitarist Course'
#  'Основы робототехники' 'chess course' 'Физика 8 класс. Дистант'
#  'Обществознание' 'Образовательная область. Познавательное развитие.'
#  'История' 'Физическая культура и спорт' 'Дистанционный курс по химии'
#  'Игровые занятия для детей 2-3 лет' 'Cooking'
#  'Скетчинг и леттеринг. 1 ступень' 'Advanced English Words' 'Основы 1.0'
#  'Создание и исследование трансгенных растений'
#  'Уравнения, неравенства и их системы. Готовимся к ОГЭ' 'Право 10Б класс.'
#  'Основы информационных технологий для доп. проф. образования'
#  'Морфология. Орфография' 'Информатика 6-9 классы. Беларусь'
#  'Copy of Олимпиада КД НТИ Junior 19/20. Технологии для мира робот'
#  'Starlight 7 Module 4 4c, 4e Lexis' 'Защита от темных искусств'
#  'Пайка. Базовые сведенияhttps://stepik.org/teach' 'Информатика 8 класс'
#  'Информатика 11 класс' 'Ilyas Karsybaev - Lab Lesson #14' 'Food'
#  'Python: шествие по граблям' 'Лепка из солёного теста '
#  'Программирование начального уровня. JavaScript' 'Развитие речи. '
#  'Биология 9 класс' 'Биология 8 класс' 'Русский язык 6 класс'
#  'Местоимение' 'Графический редактор  Pixrl'
#  'Основы проектно-исследовательской деятельности 5 класс.' 'КВИЗИУМ'
#  'математика 7' 'Мультипликация и анимация'
#  'Авиамоделизм. Основы аэродинамики и динамики полета моделей'
#  'Физика 7 класс' 'Физика 8 класс' 'Физика 9 класс' 'Физика 10 класс'
#  'ЕГЭ по информатике' 'Экономика 10 класс'
#  'Подготовка к ВПР (1) физика 7 класс 2020 ' 'Физика 11 класс'
#  'Тренажерный зал русского языка ' 'Геометрия 8 класс'
#  'Путешествие в Геометрополис' 'право' 'Интегралы (для менеджеров).'
#  'Математика для будущих школьников.' 'Математика 5 класс'
#  'Россия в правление Александра III ' 'Физиология ' '10 класс. Ток.'
#  'ЗАЧЁТ ПО ОРГАНИЧЕСКОЙ ХИМИИ' 'Вопросительные слова в Китайском языке'
#  'Клеточные автоматы' 'Математика 5 класс' 'Программирование 7м 2019-2020'
#  'Математика (6 класс)'
#  'Обучение анимации и мультимедиа в школьном курсе информатики'
#  'Обществознание 10Б' 'Сера и её свойства' 'Английский язык' '10 класс'
#  'Алгебра. 9 класс' 'Алгебра. 8 класс'
#  'Занимательная физика 4: создание вселенной'
#  'Занимательная физика 2: тайны мироздания' 'НКО-удалёнка без боли'
#  'Увлекательная математика 4: мир на координатном поле'
#  'Основы базы данных \\ СДИ' 'Естествознание 3-4: юные исследователи'
#  'Всеобщая история' 'Естествознание 1-2: домашняя лаборатория'
#  'Биология 7 класс' 'Русский язык 8 класс' 'МДК 01.01 группа 291'
#  'Литература 8 класс' 'Литература 7класс'
#  'Основы счета 3-4: настольные игры'
#  'Основы счета 1-2: экономика в джунглях'
#  'Уроки по физической культуре для первых классов' 'ГЕО' 'Математика'
#  'Русская литература' 'Беларуская літаратура 4 клас'
#  'Русский язык 4 класс'
#  'Обработка изображения средствами векторного редактора'
#  'Глава 3. Начала программирования' '2 класс' 'Информатика 11 класс'
#  'Редакция изображений в программе "Pixlr"'
#  '11 класс информатика (базовый)' 'тест'
#  'Цифровые технологии: что помогает нам создавать будущее?'
#  'Защищенный договор: блокчейн-программирование и смарт-контракты'
#  'Астрономия 11 класс' 'Цифровая экономика: как технологии меняют рынок'
#  'Кибербезопасность: что нужно знать о новом виде защиты?'
#  'Революция в финансах: криптоэкономика и технология блокчейн'
#  'Фоторедактор Pixlr Editor' '8 класс Информатика Лицей 67' 'Химия ' 'ЕГЭ'
#  'Трудовое обучение (обслуживающий труд) 7 класс'
#  'Трудовое обучение (обслуживающий труд) 6 класс' 'Информатика'
#  'Трудовое обучение (обслуживающий труд)  5 класс'
#  '«Увлекательная математика 2: космические путешествия»' 'ОБЖ 5 класс'
#  'Биология 9 класс' 'Медицинская подготовка 11 класс' 'Курс для Эмилии'
#  'Биохимия растений' 'Геометрия 9'
#  'Биохимия сельскохозяйственной продукции'
#  'ЕН.02 ДИСКРЕТНАЯ МАТЕМАТИКА С ЭЛЕМЕНТАМИ МАТЕМАТИЧЕСКОЙ ЛОГИКИ'
#  'Окружающий мир "От земли до неба"'
#  'Рассказ Ф. А. Искандера "Тринадцатый подвиг Геракла"'
#  'Медицинская подготовка 10 класс' 'Программируем с Alice (1 год)'
#  'Пром. дизайн _ проектные группы' 'Системы счисления'
#  'Уроки технологии. IT (Геворкян Ф.Т.)' 'Белорусский язык 4 класс'
#  'Шаг к писательскому мастерству. Фанфикшн'
#  'Базовая техника киокусинкай (2 - 1 кю)' 'Алгебра-10 хим-био' '1 класс'
#  'Шахматы. Начальный курс.' 'test' 'Изготовление мягкой игрушки-сувенира.'
#  'Финансовая грамотность' 'Как сделать бота "Вконтакте"' 'Химия 8 класс'
#  'Пром. дизайн _ базовая группа' 'Информатика10 класс'
#  'Юный исследователь' 'Аэро' 'Поднебесная глазами студента'
#  'Русский язык 5 класс' 'Arduino в online: быстрый старт в Tinkercad'
#  'ЕН.01 ЭЛЕМЕНТЫ ВЫСШЕЙ МАТЕМАТИКИ'
#  'Моделирование в Blender 3D v2.8 для начинающих' 'Информатика 9 класс'
#  'огэ ' 'МДК 01.01 Эксплуатация кранов металлургического производства'
#  'Музыка 273 - 4 класс' 'English Grammar ' 'Информатика 7 класс'
#  'Информатика дистанционно (6-11 классы)' 'Информатика 6 класс'
#  'Информатика 6 класс' 'Мой дом - мой образ жизни.' 'ОБЖ-9 кл'
#  'Алгебра. ОГЭ 2020г 9 класс' 'Информатика 8 класс'
#  'Starlight 7 Module 4 4b Home remedies' 'Рисос 2020 весна'
#  '11 класс информатика (ФизМат)' 'Общие сведения об Интернете вещей'
#  'Разработка квестов для школьного курса информатики'
#  '10 класс информатика' 'Дистанционное обучение' '9 класс информатика'
#  'Практический курс использования СУБД MySQL' 'История России 8 класс'
#  'Quality Assurance Course / Napoleon IT School - Тестовое задание'
#  'Индустриальные технологии 6 класс' 'Информатика 10А'
#  'Общий курс железных дорог ' '1' 'физика 7-11 классы Беларусь'
#  'Публичная защита проекта'
#  'Китайский сленг, и как его употреблять в речи' 'Геометрия 8 класс'
#  'Алгебра 8 класс' 'Геометрия 7 класс' 'Алгебра 7 класс'
#  'Математика 5 класс' 'Геометрия. 9 класс'
#  '5 класс Технология (индустриальные технологии)'
#  'Курс для проектников VR\\AR' 'Базовый курс по VR\\AR'
#  'Основы программирования' 'Дистанционное обучение АЭРО-П1'
#  '"ПРАКТИКУМ ПО ПРОДАЖАМ"' 'Starlight 6 Module 4 4a (lexis, grammar)'
#  'Инженерно-техническая подготовка. Блок Радиоэлектроника.'
#  'Физика (Лицей № 393, г.Санкт-Петербург)'
#  'Компьютер как универсальное устройство для работы с информацией'
#  'Знакомство с Lego Wedo' '8 класс информатика' 'Геометрия. 8 класс'
#  '7 класс информатика' 'Тренер iceDay' 'БИОЛОГИЯ 10 класс'
#  'информатика 7 класс' 'Маркетинг для стоматологии '
#  'Адский месяц. Русский язык'
#  'Введение в  векторную графику. Основы работы в  CorelDRAW'
#  'История России 9 класс'
#  'Copy of Дистанционное обучение. Математика 6 класс МАОУ СОШ 12 Т'
#  'Основные классы неорганических соединений'
#  'Starlight 7 Module 4 4a (lexis, grammar)' 'Математика 11А'
#  'Статистическая физика и термодинамика'
#  'Агроэкология. Комнатное цветоводство. Крутий И. И .'
#  'Литература. 7 "Б" класс' '3D-МОДЕЛИРОВАНИЕ'
#  'SoftSkills c Яниной Коноваловой' 'История России'
#  'Информатика 6 -11 класс. Беларусь.' 'Экономика' 'Музыка 273 - 3 класс'
#  'Информатика 10Б' 'Информатика 10А' 'Литература. 8 класс'
#  'Обществознание 7 класс'
#  'МАНиТТ (Фомина Кристина Константиновна. ГАОУ АО ДО РШТ)'
#  'Геометрия 8 класс "Окружность"' 'Физика. 10 класс. Дистант'
#  'Знакомство с распознаванием объектов'
#  'Основы работы в трёхмерном редакторе Blender'
#  'Информационные технологии в индустрии гостеприимства'
#  'Беспилотная авиация. Покоряй воздух - побеждай в Кванториаде'
#  'Фармацевтическая технология (промышленная), 4 курс.' 'Введение в химию '
#  'Русский язык' 'Технология 8 класс' 'Обществознание 6 класс'
#  '11 класс - общие биологические закономерности' 'ОП.10 ЧИСЛЕННЫЕ МЕТОДЫ'
#  'Горностай 9-2. Логика'
#  'ДООП "Робототехника" Модуль-вектор «Вызов» второй год обучения'
#  'Анатомия' 'Тесты по МХК'
#  'Теория проектирования собственного мультикоптера' 'Физическая культура'
#  '127-2020-ЧЕРЧЕНИЕ' 'Металлы' 'Музыка 273 - 1 класс'
#  'Основы программирования'
#  'Буковская А. А. Продлёнка на удалёнке 1кл. IV четверть 2019/2020'
#  'ОБЖ-8 кл.' 'МДК 02.03 Продуктивная деятельность дошкольников'
#  'Web - программирование. Создаем собственный сайт. '
#  'Русская Классическая школа. 1 класс' 'Искусство Древнего Рима'
#  'Информационные системы управления проектами (MS Project)'
#  'Le Français: des expressions de préférence (8-9 classe)'
#  'Физика. 9 класс. Дистант'
#  'Как работать с векторной графикой в онлайн-редакторе Method Draw'
#  'массивы' 'Физика 7 класс' 'Тригонометрические уравнения и неравенства'
#  'Локальные и глобальные сети'
#  'Уроки технологии. Промышленный дизайн (Васильева В.А.)'
#  'Физика. 7 класс. Дистант'
#  'The Present-Simple Tense/ The Past-Simple.Правила и практика.'
#  'Скорочтение и развитие памяти. 1 Ступень.'
#  'Программирование на Python11 класс'
#  'История и культура Санкт-Петербурга' 'Copy of Имя числительное'
#  'Информатика 1368'
#  'Практический курс русского языка: экспериментальная копия'
#  'Итоговая контрольная работа по тригонометрии (10 класс)' 'БПЛА Junior'
#  'Введение в дистанционное обучение' 'Медиашкола "Спутник": фактчекинг'
#  'Физика 8 класс' 'Английский язык. 8 класс'
#  'Английский язык. Времена и основы грамматики. Уровень 1'
#  'Башкирский язык 6 класс' 'Башкирская литература10 класс'
#  'Экономическая оценка компенсаций за негативное воздействие на ОС'
#  'Русский язык. 7 "Б" класс' 'Hellomalikum' '10б. Информатика'
#  'Физиология и биохимия растений' 'Информатика для малышей'
#  'Информатика ОГЭ' 'Мини-курс "Программирование в Scratch для детей"'
#  'Альдегиды и кетоны' 'Исполнитель Кукарача' 'Python для Кванториум'
#  'Имя числительное' 'Производная' 'Музыка 273 - 2 класс'
#  'Физика — курс Суслова А А'
#  'Профильная смена Республики Татарстан по робототехнике' 'Питон'
#  'Информационная безопасность: как защитить себя и свои аккаунты'
#  'Тест на гея' 'Математика 8 класс' 'Мир вокруг нас (Данилкив Н.О.)'
#  'ПОВТОРЯЕМ ОБЩУЮ БИОЛОГИЮ' 'Контрольная работа 6А, 6Б Гимназия Арт-Этюд'
#  'Программирование на Python. Часть 1' '9 класс. IV четверть'
#  'Программирование Android в MIT App Inventor 2' 'Биология'
#  'Компетенции цифровой экономики - профессионалам будущего!'
#  'Проектирование роботизированной колёсной платформы. Начало'
#  'Алгоритмика 5 класс' 'Расширенные возможности Excel'
#  'мы русские, с нами бог' 'Мир исследователя (2 год Данилкив Н.О.)'
#  'Основы мобильной робототехники.'
#  'Autodesk Inventor, основы трёхмерного моделирования' 'Русский язык СПО'
#  '«Мир под микроскопом: вдохновение, технологии, разработка»'
#  'Мир исследователя (3 год Данилкив Н.О.)' 'Excel для новичков'
#  'Курс "Удаленный сотрудник"' 'Русский язык 5 класс'
#  'Мастер маникюра за 5 уроков: 4 урока в трёх видео + онлайн урок.'
#  'Металлы и сплавы. (5 класс.)' 'Повторение. Окружность. 9 класс'
#  'Русский язык 7 класс' 'Математика (3 класс): Дополнительные задания'
#  'Математика — курс Суслова А А']

# %%
text = []

titles = df.title.values
for title in titles:
    text.append(title)

summary = df.summary.values
for s in summary:
    text.append(s)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import DictVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# %%
#vectorizer = CountVectorizer()
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(text)

#print(vectorizer.get_feature_names())

true_k = 3
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
y_km = model.fit_predict(X)

# %%
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print
# Out:
# Top terms per cluster:
# Cluster 0:
#  химии
#  по
#  веществ
#  курса
#  при
#  органических
#  соединений
#  определять
#  реакций
#  их
# Cluster 1:
#  курс
#  для
#  на
#  по
#  класс
#  как
#  курса
#  вы
#  из
#  основы
# Cluster 2:
#  не
#  каждый
#  на
#  урок
#  класс
#  по
#  курс
#  вы
#  понять
#  так
